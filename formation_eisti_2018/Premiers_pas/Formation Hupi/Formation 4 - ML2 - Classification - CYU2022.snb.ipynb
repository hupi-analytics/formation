// %% [markdown]
// <img src=http://fd.perso.eisti.fr/Logos/TORUS2.png>

// %% [markdown]
// To illustrate classification algorithms, an example of Random Forest will be enough!
//
// "Random forests or random decision forests are an ensemble learning method for classification, regression and other tasks, that operate by constructing a multitude of decision trees at training time and outputting the class that is the mode of the classes (classification) or mean prediction (regression) of the individual trees. Random decision forests correct for decision trees' habit of overfitting to their training set"
//
// (source : https://en.wikipedia.org/wiki/Random_forest)

// %% [markdown]
// ### Read dataset (csv format) from HDFS
//
// Here we use the dataset from https://archive.ics.uci.edu/ml/datasets/Haberman%27s+Survival
//
// The target variable will be Survival status (1 - the patient survived 5 years or longer and 2 - the patient died within 5 year ) and the variables descriptives are :
// - Age of patient at time of operation (numerical)
// - Patient's year of operation (year - 1900, numerical)
// - Number of positive axillary nodes detected (numerical)

// %%
import org.apache.spark.sql._            
val spark = SparkSession.builder().getOrCreate()

val data = spark.read.format("com.databricks.spark.csv")
              .option("header", "true").option("inferSchema", "true") 
              .load("hdfs://hupi-factory-02-01-01-01/user/hupi/dataset_torusVN/formation4_ML/haberman.csv")
              .withColumn("status", when($"status"===2, 0).otherwise($"status"))
// Out:
// import org.apache.spark.sql._
// spark: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@638b040b
// data: org.apache.spark.sql.DataFrame = [age: int, nbYearOperation: int ... 2 more fields]

// %%
data.show()
// Out:
// +---+---------------+-------------+------+
// |age|nbYearOperation|nbPosAxillary|status|
// +---+---------------+-------------+------+
// | 30|             64|            1|     1|
// | 30|             62|            3|     1|
// | 30|             65|            0|     1|
// | 31|             59|            2|     1|
// | 31|             65|            4|     1|
// | 33|             58|           10|     1|
// | 33|             60|            0|     1|
// | 34|             59|            0|     0|
// | 34|             66|            9|     0|
// | 34|             58|           30|     1|
// | 34|             60|            1|     1|
// | 34|             61|           10|     1|
// | 34|             67|            7|     1|
// | 34|             60|            0|     1|
// | 35|             64|           13|     1|
// | 35|             63|            0|     1|
// | 36|             60|            1|     1|
// | 36|             69|            0|     1|
// | 37|             60|            0|     1|
// | 37|             63|            0|     1|
// +---+---------------+-------------+------+
// only showing top 20 rows

// %%
data.printSchema()
// Out:
// root
//  |-- age: integer (nullable = true)
//  |-- nbYearOperation: integer (nullable = true)
//  |-- nbPosAxillary: integer (nullable = true)
//  |-- status: integer (nullable = true)

// %%
// Analyse des données
data.describe()
// Out:
// res4: org.apache.spark.sql.DataFrame = [summary: string, age: string ... 3 more fields]
// <div class="df-canvas">
//       <script data-this="{&quot;dataId&quot;:&quot;anonf869293929a85cebdf5db882722eb19b&quot;,&quot;partitionIndexId&quot;:&quot;anon6920f0dba2472fbe2bb90d53ff717141&quot;,&quot;numPartitions&quot;:1,&quot;dfSchema&quot;:{&quot;type&quot;:&quot;struct&quot;,&quot;fields&quot;:[{&quot;name&quot;:&quot;summary&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;age&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;nbYearOperation&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;nbPosAxillary&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}},{&quot;name&quot;:&quot;status&quot;,&quot;type&quot;:&quot;string&quot;,&quot;nullable&quot;:true,&quot;metadata&quot;:{}}]}}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/dataframe','../javascripts/notebook/consoleDir'],
//       function(dataframe, extension) {
//         dataframe.call(data, this, extension);
//       }
//     );/*]]>*/</script>
//       <link rel="stylesheet" href="/assets/stylesheets/ipython/css/dataframe.css" type="text/css"/>
//     </div>

// %% [markdown]
// ## Pre-processing
// Pour appliquer le modèle Random Forest, il faut effectuer plusieures étapes de pre-processing.
// Il faut tout d'abord indexer les données.
//
// **Vector Assembler :**
// On regroupe toutes les variables explicatives dans une seule colonne. La colonne "features" on aura toutes les informations des variables pour chaque observation.

// %%
import org.apache.spark.ml.feature.VectorAssembler
import org.apache.spark.ml.Pipeline
import org.apache.spark.ml.classification.{RandomForestClassificationModel, RandomForestClassifier}
import org.apache.spark.ml.evaluation.MulticlassClassificationEvaluator
import org.apache.spark.ml.feature.{IndexToString, StringIndexer, VectorIndexer}
// Out:
// import org.apache.spark.ml.feature.VectorAssembler
// import org.apache.spark.ml.Pipeline
// import org.apache.spark.ml.classification.{RandomForestClassificationModel, RandomForestClassifier}
// import org.apache.spark.ml.evaluation.MulticlassClassificationEvaluator
// import org.apache.spark.ml.feature.{IndexToString, StringIndexer, VectorIndexer}

// %%
// Indexer la variable à expliquer
val labelIndexer = new StringIndexer()
  .setInputCol("status")
  .setOutputCol("indexedLabel")
  .fit(data)
// Out:
// labelIndexer: org.apache.spark.ml.feature.StringIndexerModel = strIdx_e0913f8d049a

// %%
// Indexer les variables explicatives et les assembler
val assembler = new VectorAssembler()
  .setInputCols(Array("age", "nbYearOperation", "nbPosAxillary"))
  .setOutputCol("features")

val featureIndexer = new VectorIndexer()
  .setInputCol("features")
  .setOutputCol("indexedFeatures")
  .setMaxCategories(4)
// Out:
// assembler: org.apache.spark.ml.feature.VectorAssembler = vecAssembler_3a83610f5146
// featureIndexer: org.apache.spark.ml.feature.VectorIndexer = vecIdx_9bd4bd6564dd

// %%
// Convert indexed labels back to original labels.
val labelConverter = new IndexToString()
  .setInputCol("prediction")
  .setOutputCol("predictedLabel")
// Out:
// labelConverter: org.apache.spark.ml.feature.IndexToString = idxToStr_7aa9872da46b

// %% [markdown]
// ## Train-Test split
// On choisit de séparer notre jeu de données avec 70% des données pour la phase d'entraînement et les 30% restant pour la phase de test.

// %%
// Split the data into training and test sets (30% held out for testing).
val Array(trainingData, testData) = data.randomSplit(Array(0.7, 0.3), seed = 11L)
// Out:
// trainingData: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [age: int, nbYearOperation: int ... 2 more fields]
// testData: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [age: int, nbYearOperation: int ... 2 more fields]

// %% [markdown]
// ## Build a Random Forest model
// Il faut instantier le modèle.

// %%
// Train a RandomForest model.
val rf = new RandomForestClassifier()
  .setLabelCol("indexedLabel")
  .setFeaturesCol("indexedFeatures")
  .setNumTrees(10)
//   .setMaxDepth(4)
//   .setMaxBins(32)
//   .setImpurity("gini")
//   .setFeatureSubsetStrategy("auto")
// Out:
// rf: org.apache.spark.ml.classification.RandomForestClassifier = rfc_30ee4740762f

// %% [markdown]
// ## Pipeline construction

// %%
// Chain indexers and forest in a Pipeline.
val pipeline = new Pipeline()
  .setStages(Array(labelIndexer, assembler, featureIndexer, rf))
// Out:
// pipeline: org.apache.spark.ml.Pipeline = pipeline_09be084cc8e9

// %% [markdown]
// ## Training

// %%
// Train model. This also runs the indexers.
val model = pipeline.fit(trainingData)
// Out:
// model: org.apache.spark.ml.PipelineModel = pipeline_09be084cc8e9

// %% [markdown]
// ## Make predictions

// %%
// Make predictions.
val predictions = model.transform(testData)
                        .withColumn("prediction", when($"prediction" === 0, 1).otherwise(0))
                        .withColumn("prediction", $"prediction".cast("Double"))
// Out:
// predictions: org.apache.spark.sql.DataFrame = [age: int, nbYearOperation: int ... 8 more fields]

// %%
predictions.show()
// Out:
// +---+---------------+-------------+------+------------+----------------+----------------+--------------------+--------------------+----------+
// |age|nbYearOperation|nbPosAxillary|status|indexedLabel|        features| indexedFeatures|       rawPrediction|         probability|prediction|
// +---+---------------+-------------+------+------------+----------------+----------------+--------------------+--------------------+----------+
// | 30|             65|            0|     1|         0.0| [30.0,65.0,0.0]| [30.0,65.0,0.0]|[9.35321551300932...|[0.93532155130093...|       1.0|
// | 31|             59|            2|     1|         0.0| [31.0,59.0,2.0]| [31.0,59.0,2.0]|           [8.5,1.5]|         [0.85,0.15]|       1.0|
// | 34|             60|            0|     1|         0.0| [34.0,60.0,0.0]| [34.0,60.0,0.0]|[9.35321551300932...|[0.93532155130093...|       1.0|
// | 34|             60|            1|     1|         0.0| [34.0,60.0,1.0]| [34.0,60.0,1.0]|[9.85321551300932...|[0.98532155130093...|       1.0|
// | 34|             61|           10|     1|         0.0|[34.0,61.0,10.0]|[34.0,61.0,10.0]|[9.14285714285714...|[0.91428571428571...|       1.0|
// | 34|             66|            9|     0|         1.0| [34.0,66.0,9.0]| [34.0,66.0,9.0]|[9.14285714285714...|[0.91428571428571...|       1.0|
// | 37|             60|           15|     1|         0.0|[37.0,60.0,15.0]|[37.0,60.0,15.0]|[7.14285714285714...|[0.71428571428571...|       1.0|
// | 37|             63|            0|     1|         0.0| [37.0,63.0,0.0]| [37.0,63.0,0.0]|[9.78654884634266...|[0.97865488463426...|       1.0|
// | 37|             63|            0|     1|         0.0| [37.0,63.0,0.0]| [37.0,63.0,0.0]|[9.78654884634266...|[0.97865488463426...|       1.0|
// | 38|             69|           21|     0|         1.0|[38.0,69.0,21.0]|[38.0,69.0,21.0]|           [8.5,1.5]|         [0.85,0.15]|       1.0|
// | 39|             67|            0|     1|         0.0| [39.0,67.0,0.0]| [39.0,67.0,0.0]|[5.34457171778016...|[0.53445717177801...|       1.0|
// | 40|             58|            2|     1|         0.0| [40.0,58.0,2.0]| [40.0,58.0,2.0]|[8.43570836423927...|[0.84357083642392...|       1.0|
// | 40|             65|            0|     1|         0.0| [40.0,65.0,0.0]| [40.0,65.0,0.0]|[8.77314314635159...|[0.87731431463515...|       1.0|
// | 41|             64|            0|     0|         1.0| [41.0,64.0,0.0]| [41.0,64.0,0.0]|[8.77314314635159...|[0.87731431463515...|       1.0|
// | 41|             65|            0|     1|         0.0| [41.0,65.0,0.0]| [41.0,65.0,0.0]|[8.77314314635159...|[0.87731431463515...|       1.0|
// | 41|             67|            0|     0|         1.0| [41.0,67.0,0.0]| [41.0,67.0,0.0]|[6.20171457492302...|[0.62017145749230...|       1.0|
// | 42|             63|            1|     1|         0.0| [42.0,63.0,1.0]| [42.0,63.0,1.0]|[7.99923642331966...|[0.79992364233196...|       1.0|
// | 43|             58|           52|     0|         1.0|[43.0,58.0,52.0]|[43.0,58.0,52.0]|[2.82352941176470...|[0.28235294117647...|       0.0|
// | 43|             63|           14|     1|         0.0|[43.0,63.0,14.0]|[43.0,63.0,14.0]|[4.57179966003495...|[0.45717996600349...|       0.0|
// | 43|             64|            0|     0|         1.0| [43.0,64.0,0.0]| [43.0,64.0,0.0]|[6.95484249275682...|[0.69548424927568...|       1.0|
// +---+---------------+-------------+------+------------+----------------+----------------+--------------------+--------------------+----------+
// only showing top 20 rows

// %% [markdown]
// ## Analyser les résultats
// On veut obtenir un score, mais aussi ressortir l'arbre de décision construit lors de l'entraînement.

// %%
// Select (prediction, true label) and compute test error.
val evaluator = new MulticlassClassificationEvaluator()
  .setLabelCol("status")
  .setPredictionCol("prediction")
  .setMetricName("accuracy")

val accuracy = evaluator.evaluate(predictions)
println(s"Test Error = ${(1.0 - accuracy)}")

val rfModel = model.stages(3).asInstanceOf[RandomForestClassificationModel]
println(s"Learned classification forest model:\n ${rfModel.toDebugString}")
// Out:
// Test Error = 0.2954545454545454
// Learned classification forest model:
//  RandomForestClassificationModel (uid=rfc_b27bebea91dd) with 10 trees
//   Tree 0 (weight 1.0):
//     If (feature 2 <= 14.0)
//      If (feature 0 <= 41.0)
//       If (feature 1 <= 59.0)
//        If (feature 0 <= 34.0)
//         If (feature 2 <= 0.0)
//          Predict: 1.0
//         Else (feature 2 > 0.0)
//          Predict: 0.0
//        Else (feature 0 > 34.0)
//         Predict: 0.0
//       Else (feature 1 > 59.0)
//        Predict: 0.0
//      Else (feature 0 > 41.0)
//       If (feature 0 <= 54.0)
//        If (feature 2 <= 1.0)
//         If (feature 1 <= 62.0)
//          Predict: 0.0
//         Else (feature 1 > 62.0)
//          Predict: 1.0
//        Else (feature 2 > 1.0)
//         If (feature 1 <= 61.0)
//          Predict: 0.0
//         Else (feature 1 > 61.0)
//          Predict: 1.0
//       Else (feature 0 > 54.0)
//        If (feature 1 <= 65.0)
//         If (feature 1 <= 64.0)
//          Predict: 0.0
//         Else (feature 1 > 64.0)
//          Predict: 1.0
//        Else (feature 1 > 65.0)
//         Predict: 0.0
//     Else (feature 2 > 14.0)
//      If (feature 0 <= 34.0)
//       Predict: 0.0
//      Else (feature 0 > 34.0)
//       If (feature 1 <= 65.0)
//        If (feature 0 <= 60.0)
//         Predict: 1.0
//        Else (feature 0 > 60.0)
//         If (feature 0 <= 64.0)
//          Predict: 0.0
//         Else (feature 0 > 64.0)
//          Predict: 1.0
//       Else (feature 1 > 65.0)
//        Predict: 0.0
//   Tree 1 (weight 1.0):
//     If (feature 2 <= 1.0)
//      If (feature 1 <= 58.0)
//       If (feature 2 <= 0.0)
//        If (feature 0 <= 39.0)
//         Predict: 0.0
//        Else (feature 0 > 39.0)
//         Predict: 1.0
//       Else (feature 2 > 0.0)
//        Predict: 0.0
//      Else (feature 1 > 58.0)
//       If (feature 0 <= 70.0)
//        If (feature 1 <= 59.0)
//         If (feature 0 <= 42.0)
//          Predict: 1.0
//         Else (feature 0 > 42.0)
//          Predict: 0.0
//        Else (feature 1 > 59.0)
//         If (feature 1 <= 68.0)
//          Predict: 0.0
//         Else (feature 1 > 68.0)
//          Predict: 0.0
//       Else (feature 0 > 70.0)
//        If (feature 1 <= 63.0)
//         If (feature 1 <= 62.0)
//          Predict: 0.0
//         Else (feature 1 > 62.0)
//          Predict: 1.0
//        Else (feature 1 > 63.0)
//         Predict: 0.0
//     Else (feature 2 > 1.0)
//      If (feature 2 <= 22.0)
//       If (feature 0 <= 42.0)
//        Predict: 0.0
//       Else (feature 0 > 42.0)
//        If (feature 0 <= 46.0)
//         If (feature 0 <= 43.0)
//          Predict: 0.0
//         Else (feature 0 > 43.0)
//          Predict: 1.0
//        Else (feature 0 > 46.0)
//         If (feature 1 <= 62.0)
//          Predict: 0.0
//         Else (feature 1 > 62.0)
//          Predict: 0.0
//      Else (feature 2 > 22.0)
//       If (feature 2 <= 24.0)
//        Predict: 1.0
//       Else (feature 2 > 24.0)
//        Predict: 0.0
//   Tree 2 (weight 1.0):
//     If (feature 0 <= 38.0)
//      Predict: 0.0
//     Else (feature 0 > 38.0)
//      If (feature 2 <= 5.0)
//       If (feature 2 <= 0.0)
//        If (feature 0 <= 39.0)
//         Predict: 1.0
//        Else (feature 0 > 39.0)
//         If (feature 0 <= 50.0)
//          Predict: 0.0
//         Else (feature 0 > 50.0)
//          Predict: 0.0
//       Else (feature 2 > 0.0)
//        If (feature 0 <= 59.0)
//         If (feature 1 <= 68.0)
//          Predict: 0.0
//         Else (feature 1 > 68.0)
//          Predict: 1.0
//        Else (feature 0 > 59.0)
//         If (feature 1 <= 59.0)
//          Predict: 0.0
//         Else (feature 1 > 59.0)
//          Predict: 1.0
//      Else (feature 2 > 5.0)
//       If (feature 2 <= 22.0)
//        If (feature 0 <= 42.0)
//         Predict: 0.0
//        Else (feature 0 > 42.0)
//         If (feature 1 <= 67.0)
//          Predict: 1.0
//         Else (feature 1 > 67.0)
//          Predict: 0.0
//       Else (feature 2 > 22.0)
//        If (feature 0 <= 59.0)
//         Predict: 1.0
//        Else (feature 0 > 59.0)
//         Predict: 0.0
//   Tree 3 (weight 1.0):
//     If (feature 2 <= 4.0)
//      If (feature 0 <= 43.0)
//       If (feature 1 <= 66.0)
//        If (feature 1 <= 58.0)
//         Predict: 0.0
//        Else (feature 1 > 58.0)
//         If (feature 1 <= 59.0)
//          Predict: 1.0
//         Else (feature 1 > 59.0)
//          Predict: 0.0
//       Else (feature 1 > 66.0)
//        Predict: 1.0
//      Else (feature 0 > 43.0)
//       If (feature 0 <= 60.0)
//        If (feature 0 <= 52.0)
//         If (feature 1 <= 59.0)
//          Predict: 0.0
//         Else (feature 1 > 59.0)
//          Predict: 0.0
//        Else (feature 0 > 52.0)
//         Predict: 0.0
//       Else (feature 0 > 60.0)
//        If (feature 0 <= 61.0)
//         Predict: 1.0
//        Else (feature 0 > 61.0)
//         If (feature 1 <= 58.0)
//          Predict: 0.0
//         Else (feature 1 > 58.0)
//          Predict: 0.0
//     Else (feature 2 > 4.0)
//      If (feature 1 <= 67.0)
//       If (feature 1 <= 59.0)
//        If (feature 2 <= 8.0)
//         Predict: 0.0
//        Else (feature 2 > 8.0)
//         If (feature 0 <= 34.0)
//          Predict: 0.0
//         Else (feature 0 > 34.0)
//          Predict: 1.0
//       Else (feature 1 > 59.0)
//        If (feature 2 <= 6.0)
//         Predict: 1.0
//        Else (feature 2 > 6.0)
//         If (feature 2 <= 8.0)
//          Predict: 0.0
//         Else (feature 2 > 8.0)
//          Predict: 1.0
//      Else (feature 1 > 67.0)
//       Predict: 0.0
//   Tree 4 (weight 1.0):
//     If (feature 2 <= 1.0)
//      If (feature 1 <= 64.0)
//       If (feature 1 <= 63.0)
//        If (feature 0 <= 68.0)
//         If (feature 1 <= 61.0)
//          Predict: 0.0
//         Else (feature 1 > 61.0)
//          Predict: 0.0
//        Else (feature 0 > 68.0)
//         If (feature 1 <= 58.0)
//          Predict: 1.0
//         Else (feature 1 > 58.0)
//          Predict: 0.0
//       Else (feature 1 > 63.0)
//        If (feature 0 <= 50.0)
//         If (feature 0 <= 48.0)
//          Predict: 0.0
//         Else (feature 0 > 48.0)
//          Predict: 0.0
//        Else (feature 0 > 50.0)
//         Predict: 0.0
//      Else (feature 1 > 64.0)
//       If (feature 1 <= 65.0)
//        If (feature 2 <= 0.0)
//         If (feature 0 <= 52.0)
//          Predict: 0.0
//         Else (feature 0 > 52.0)
//          Predict: 1.0
//        Else (feature 2 > 0.0)
//         Predict: 1.0
//       Else (feature 1 > 65.0)
//        If (feature 0 <= 45.0)
//         If (feature 1 <= 67.0)
//          Predict: 1.0
//         Else (feature 1 > 67.0)
//          Predict: 0.0
//        Else (feature 0 > 45.0)
//         If (feature 2 <= 0.0)
//          Predict: 0.0
//         Else (feature 2 > 0.0)
//          Predict: 0.0
//     Else (feature 2 > 1.0)
//      If (feature 0 <= 39.0)
//       Predict: 0.0
//      Else (feature 0 > 39.0)
//       If (feature 0 <= 41.0)
//        Predict: 1.0
//       Else (feature 0 > 41.0)
//        If (feature 0 <= 42.0)
//         Predict: 0.0
//        Else (feature 0 > 42.0)
//         If (feature 1 <= 63.0)
//          Predict: 1.0
//         Else (feature 1 > 63.0)
//          Predict: 0.0
//   Tree 5 (weight 1.0):
//     If (feature 2 <= 11.0)
//      If (feature 0 <= 49.0)
//       If (feature 0 <= 34.0)
//        If (feature 2 <= 0.0)
//         If (feature 1 <= 59.0)
//          Predict: 1.0
//         Else (feature 1 > 59.0)
//          Predict: 0.0
//        Else (feature 2 > 0.0)
//         Predict: 0.0
//       Else (feature 0 > 34.0)
//        If (feature 0 <= 38.0)
//         Predict: 0.0
//        Else (feature 0 > 38.0)
//         If (feature 0 <= 47.0)
//          Predict: 0.0
//         Else (feature 0 > 47.0)
//          Predict: 0.0
//      Else (feature 0 > 49.0)
//       If (feature 2 <= 0.0)
//        If (feature 0 <= 70.0)
//         If (feature 1 <= 63.0)
//          Predict: 0.0
//         Else (feature 1 > 63.0)
//          Predict: 0.0
//        Else (feature 0 > 70.0)
//         If (feature 0 <= 72.0)
//          Predict: 1.0
//         Else (feature 0 > 72.0)
//          Predict: 0.0
//       Else (feature 2 > 0.0)
//        If (feature 2 <= 8.0)
//         If (feature 0 <= 57.0)
//          Predict: 0.0
//         Else (feature 0 > 57.0)
//          Predict: 0.0
//        Else (feature 2 > 8.0)
//         Predict: 1.0
//     Else (feature 2 > 11.0)
//      If (feature 1 <= 63.0)
//       If (feature 0 <= 45.0)
//        If (feature 0 <= 44.0)
//         Predict: 1.0
//        Else (feature 0 > 44.0)
//         Predict: 0.0
//       Else (feature 0 > 45.0)
//        If (feature 1 <= 59.0)
//         Predict: 1.0
//        Else (feature 1 > 59.0)
//         If (feature 0 <= 53.0)
//          Predict: 1.0
//         Else (feature 0 > 53.0)
//          Predict: 1.0
//      Else (feature 1 > 63.0)
//       If (feature 2 <= 14.0)
//        Predict: 0.0
//       Else (feature 2 > 14.0)
//        If (feature 2 <= 15.0)
//         Predict: 1.0
//        Else (feature 2 > 15.0)
//         If (feature 0 <= 54.0)
//          Predict: 1.0
//         Else (feature 0 > 54.0)
//          Predict: 0.0
//   Tree 6 (weight 1.0):
//     If (feature 0 <= 41.0)
//      If (feature 1 <= 59.0)
//       If (feature 2 <= 0.0)
//        If (feature 0 <= 34.0)
//         Predict: 1.0
//        Else (feature 0 > 34.0)
//         Predict: 0.0
//       Else (feature 2 > 0.0)
//        Predict: 0.0
//      Else (feature 1 > 59.0)
//       Predict: 0.0
//     Else (feature 0 > 41.0)
//      If (feature 2 <= 14.0)
//       If (feature 2 <= 1.0)
//        If (feature 0 <= 47.0)
//         If (feature 1 <= 63.0)
//          Predict: 0.0
//         Else (feature 1 > 63.0)
//          Predict: 1.0
//        Else (feature 0 > 47.0)
//         If (feature 0 <= 60.0)
//          Predict: 0.0
//         Else (feature 0 > 60.0)
//          Predict: 0.0
//       Else (feature 2 > 1.0)
//        If (feature 2 <= 3.0)
//         If (feature 1 <= 68.0)
//          Predict: 0.0
//         Else (feature 1 > 68.0)
//          Predict: 1.0
//        Else (feature 2 > 3.0)
//         If (feature 0 <= 63.0)
//          Predict: 0.0
//         Else (feature 0 > 63.0)
//          Predict: 1.0
//      Else (feature 2 > 14.0)
//       If (feature 0 <= 55.0)
//        If (feature 0 <= 53.0)
//         If (feature 0 <= 42.0)
//          Predict: 0.0
//         Else (feature 0 > 42.0)
//          Predict: 1.0
//        Else (feature 0 > 53.0)
//         Predict: 0.0
//       Else (feature 0 > 55.0)
//        If (feature 2 <= 17.0)
//         Predict: 1.0
//        Else (feature 2 > 17.0)
//         If (feature 2 <= 25.0)
//          Predict: 0.0
//         Else (feature 2 > 25.0)
//          Predict: 1.0
//   Tree 7 (weight 1.0):
//     If (feature 0 <= 72.0)
//      If (feature 2 <= 10.0)
//       If (feature 0 <= 38.0)
//        If (feature 1 <= 59.0)
//         If (feature 0 <= 34.0)
//          Predict: 0.0
//         Else (feature 0 > 34.0)
//          Predict: 0.0
//        Else (feature 1 > 59.0)
//         Predict: 0.0
//       Else (feature 0 > 38.0)
//        If (feature 0 <= 47.0)
//         If (feature 1 <= 61.0)
//          Predict: 0.0
//         Else (feature 1 > 61.0)
//          Predict: 1.0
//        Else (feature 0 > 47.0)
//         If (feature 0 <= 64.0)
//          Predict: 0.0
//         Else (feature 0 > 64.0)
//          Predict: 0.0
//      Else (feature 2 > 10.0)
//       If (feature 0 <= 60.0)
//        If (feature 2 <= 22.0)
//         Predict: 0.0
//        Else (feature 2 > 22.0)
//         If (feature 2 <= 23.0)
//          Predict: 1.0
//         Else (feature 2 > 23.0)
//          Predict: 0.0
//       Else (feature 0 > 60.0)
//        If (feature 2 <= 15.0)
//         Predict: 1.0
//        Else (feature 2 > 15.0)
//         If (feature 1 <= 62.0)
//          Predict: 1.0
//         Else (feature 1 > 62.0)
//          Predict: 0.0
//     Else (feature 0 > 72.0)
//      If (feature 1 <= 58.0)
//       Predict: 1.0
//      Else (feature 1 > 58.0)
//       Predict: 0.0
//   Tree 8 (weight 1.0):
//     If (feature 0 <= 41.0)
//      If (feature 0 <= 34.0)
//       If (feature 2 <= 0.0)
//        If (feature 1 <= 59.0)
//         Predict: 1.0
//        Else (feature 1 > 59.0)
//         Predict: 0.0
//       Else (feature 2 > 0.0)
//        Predict: 0.0
//      Else (feature 0 > 34.0)
//       If (feature 1 <= 65.0)
//        Predict: 0.0
//       Else (feature 1 > 65.0)
//        If (feature 2 <= 0.0)
//         If (feature 0 <= 38.0)
//          Predict: 0.0
//         Else (feature 0 > 38.0)
//          Predict: 1.0
//        Else (feature 2 > 0.0)
//         Predict: 0.0
//     Else (feature 0 > 41.0)
//      If (feature 0 <= 46.0)
//       If (feature 2 <= 4.0)
//        If (feature 1 <= 64.0)
//         If (feature 2 <= 0.0)
//          Predict: 0.0
//         Else (feature 2 > 0.0)
//          Predict: 0.0
//        Else (feature 1 > 64.0)
//         If (feature 2 <= 0.0)
//          Predict: 0.0
//         Else (feature 2 > 0.0)
//          Predict: 1.0
//       Else (feature 2 > 4.0)
//        Predict: 1.0
//      Else (feature 0 > 46.0)
//       If (feature 1 <= 59.0)
//        If (feature 0 <= 58.0)
//         If (feature 0 <= 51.0)
//          Predict: 0.0
//         Else (feature 0 > 51.0)
//          Predict: 0.0
//        Else (feature 0 > 58.0)
//         If (feature 0 <= 68.0)
//          Predict: 1.0
//         Else (feature 0 > 68.0)
//          Predict: 1.0
//       Else (feature 1 > 59.0)
//        If (feature 2 <= 2.0)
//         If (feature 1 <= 62.0)
//          Predict: 0.0
//         Else (feature 1 > 62.0)
//          Predict: 0.0
//        Else (feature 2 > 2.0)
//         If (feature 0 <= 47.0)
//          Predict: 0.0
//         Else (feature 0 > 47.0)
//          Predict: 1.0
//   Tree 9 (weight 1.0):
//     If (feature 2 <= 11.0)
//      If (feature 0 <= 72.0)
//       If (feature 0 <= 38.0)
//        If (feature 0 <= 34.0)
//         If (feature 2 <= 0.0)
//          Predict: 0.0
//         Else (feature 2 > 0.0)
//          Predict: 0.0
//        Else (feature 0 > 34.0)
//         Predict: 0.0
//       Else (feature 0 > 38.0)
//        If (feature 2 <= 4.0)
//         If (feature 0 <= 47.0)
//          Predict: 0.0
//         Else (feature 0 > 47.0)
//          Predict: 0.0
//        Else (feature 2 > 4.0)
//         If (feature 2 <= 5.0)
//          Predict: 1.0
//         Else (feature 2 > 5.0)
//          Predict: 0.0
//      Else (feature 0 > 72.0)
//       If (feature 2 <= 0.0)
//        Predict: 0.0
//       Else (feature 2 > 0.0)
//        Predict: 1.0
//     Else (feature 2 > 11.0)
//      If (feature 1 <= 58.0)
//       Predict: 0.0
//      Else (feature 1 > 58.0)
//       If (feature 2 <= 22.0)
//        If (feature 2 <= 17.0)
//         If (feature 0 <= 45.0)
//          Predict: 0.0
//         Else (feature 0 > 45.0)
//          Predict: 1.0
//        Else (feature 2 > 17.0)
//         If (feature 0 <= 44.0)
//          Predict: 0.0
//         Else (feature 0 > 44.0)
//          Predict: 0.0
//       Else (feature 2 > 22.0)
//        Predict: 1.0

// %%
model.stages(3)
// Out:
// res36: org.apache.spark.ml.Transformer = RandomForestClassificationModel (uid=rfc_b27bebea91dd) with 10 trees
// RandomForestClassificationModel (uid=rfc_b27bebea91dd) with 10 trees

// %%
/*
// Save and load model
model.save(sc, savePath)
val sameModel = RandomForestModel.load(sc, savePath)
*/

// %% [markdown]
// # Exercice
// Appliquer un modèle de classification Regréssion Logistique et comparer les résultats des deux modèles. Il faut donc trouver des indicateurs à comparer entre eux.
//
// Documentation : https://spark.apache.org/docs/latest/ml-classification-regression.html#logistic-regression
//
// Créer une chaîne de pipeline à partir des étapes Pre-processing, jusqu'à la création du modèle.

// %%
// Preparation des données d'entrées

// %%
// Création du modèle

// %%
// Le pipeline

// %%
// Prédictions

// %%
// Analyse des résultats

// %% [markdown]
// # Correction
