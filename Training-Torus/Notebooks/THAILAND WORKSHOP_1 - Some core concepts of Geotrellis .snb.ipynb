// %% [markdown]
// # Useful links to read :
//
// http://geotrellis.readthedocs.io/en/latest/guide/core-concepts.html
//
// Github :
// https://github.com/locationtech/geotrellis
//
// Function :
// http://geotrellis.github.io/scaladocs/latest/#geotrellis.package

// %% [markdown]
// # Import libraries

// %%
import geotrellis.proj4._

import geotrellis.spark._
import geotrellis.spark.io.hadoop._
import geotrellis.spark.io.hadoop.formats._
import geotrellis.spark.io.RasterReader
import geotrellis.spark.tiling.FloatingLayoutScheme

import geotrellis.vector._

import geotrellis.raster._
import geotrellis.raster.render._
import geotrellis.raster.io.geotiff._
import geotrellis.raster.io.geotiff.reader.GeoTiffReader
import geotrellis.raster.io.geotiff.tags.TiffTags
import geotrellis.raster.io.geotiff.GeoTiff

import org.apache.hadoop.conf.Configuration
import org.apache.hadoop.fs.Path
// Out:
// import geotrellis.proj4._
// import geotrellis.spark._
// import geotrellis.spark.io.hadoop._
// import geotrellis.spark.io.hadoop.formats._
// import geotrellis.spark.io.RasterReader
// import geotrellis.spark.tiling.FloatingLayoutScheme
// import geotrellis.vector._
// import geotrellis.raster._
// import geotrellis.raster.render._
// import geotrellis.raster.io.geotiff._
// import geotrellis.raster.io.geotiff.reader.GeoTiffReader
// import geotrellis.raster.io.geotiff.tags.TiffTags
// import geotrellis.raster.io.geotiff.GeoTiff
// import org.apache.hadoop.conf.Configuration
// import org.apache.hadoop.fs.Path

// %% [markdown]
// # Important variables (to run everytime we use Geotrellis)

// %%
// implicit variable (important variables to run the functions in the geotrellis library)
implicit val sparkContext = sc

val rr = implicitly[RasterReader[HadoopGeoTiffRDD.Options, (ProjectedExtent, Tile)]]
// Out:
// sparkContext: org.apache.spark.SparkContext = org.apache.spark.SparkContext@3fc79c5f
// rr: geotrellis.spark.io.RasterReader[geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options,(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = geotrellis.spark.io.RasterReader$$anon$1@1525d784

// %% [markdown]
// # Parameters

// %%
val HdfsUrl = "hdfs://hupi-factory-02-01-01-01/"
val dataRepo = "user/factory02/thailand_workshop/data_usgs/"

// Landsat8 
val bandPath = "LC08_L1TP_125052_20171231_20180103_01_T1"
// Out:
// HdfsUrl: String = hdfs://hupi-factory-02-01-01-01/
// dataRepo: String = user/factory02/thailand_workshop/data_usgs/
// bandPath: String = LC08_L1TP_125052_20171231_20180103_01_T1

// %% [markdown]
// # Load GeoTiff from HDFS
//
// When we read GeoTiff from HDFS, we will have a RDD[ProjectedExtent, Tile]
//
// From the documents of Geotrellis, some important concepts to know beforehand :
//
// - Tile is "A grid of numeric cells that represent some data on the Earth"
// - Cell is "A single unit of data in some grid, also called a Location in GIS"
// - In ProjectedExtent, we have extent and CRS. For definition, "Extent: or "Bounding Box" represents some area on the Earth".
//
// Here we have 2 ways to read, it's just 2 different ways to do the repartition

// %%
// To make the notebook run more efficiently 
val options =
HadoopGeoTiffRDD.Options(
  numPartitions = Some(100)
)

// %%
// First option
val band = HadoopGeoTiffRDD[ProjectedExtent, Tile](
      new Path(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF"), 
      options).map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType)))
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[4] at map at <console>:109

// %%
// Second option
val band = sc.hadoopGeoTiffRDD(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF")
        .map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType))).repartition(100)
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[13] at repartition at <console>:106

// %% [markdown]
// # Inside RDD[ProjectedExtent, Tile]..

// %%
// This version of Spark divides one GeoTiff into multiples Tiles (SingleBand or MultiBand)
// So if we count the number of observations in RDD, we will have number of Tiles
println("Number of Tiles in this band is " + band.count())
// Out:
// Number of Tiles in this band is 930

// %%
// Number of Cells
println("Number of Cells in this band is " + band.map(l => l._2.toArrayDouble()).flatMap(l => l).count())
// Out:
// Number of Cells in this band is 58378481

// %%
// If we take some observations
band.take(5)
// Out:
// res11: Array[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = Array((ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@3e0b6072,256,256)), (ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@3a46899e,256,256)), (ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@39c8e59b,256,256)), (ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@7b5806cd,256,256)), (ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@1e35f124,256,256)))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon4c9f6d2b193ec84a29645cce2ac2f3db&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1644787086&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1644787086"><li>
//               <a href="#tab1644787086-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1644787086-1"><i class="fa fa-pie-chart"/></a>
//             </li><li>
//               <a href="#tab1644787086-2"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1644787086"><div class="tab-pane" id="tab1644787086-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon1b87225338e3f3eb88997708cc7c433b&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3e0b6072,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3a46899e,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@39c8e59b,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7b5806cd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@1e35f124,256,256)&quot;}],&quot;genId&quot;:&quot;277971368&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonc6abf647771b2f9dc08b8c49698ab649&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond716e9487d46a6842ac1bd5e42f29f27&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1644787086-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone5b0c89799fb922f695288c90d2fd54f&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3e0b6072,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3a46899e,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@39c8e59b,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7b5806cd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@1e35f124,256,256)&quot;}],&quot;genId&quot;:&quot;705607761&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pieChart'],
//       function(playground, _magicpieChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpieChart,
//     "o": {"series":"_1","p":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anone2d65ca890b8a4e73a71a12a2817540a&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon9d8e30a2607f7af3af1f2d788a5376a1&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1644787086-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon06400aa97662803f42aa6ed90633bac1&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3e0b6072,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3a46899e,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@39c8e59b,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7b5806cd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@1e35f124,256,256)&quot;}],&quot;genId&quot;:&quot;1142055708&quot;}" type="text/x-scoped-javascript">/*<![C

// %%
// ProjectedExtent
band.map(l => l._1).take(10)
// Out:
// res13: Array[geotrellis.vector.ProjectedExtent] = Array(ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1202415.0, 712905.0, 1210095.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1256175.0, 559305.0, 1263855.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1194735.0, 636105.0, 1202415.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1187055.0, 712905.0, 1194735.0),EPSG:32648), ProjectedExtent(Extent(559305.0, 137905...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonda50f852785478f3999f930a2d440446&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot
quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["xmin","ymin","xmax","ymax","width","height"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anona91cbc29ff67187856514976b1c87493&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon598ea290fe4c89d8c297b83d16b54574&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1426035885-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonaeaf5b0e9a253b3b7b3c765b747cebe9&quot;,&quot;dataInit&quot;:[{&quot;ymax&quot;:1386735,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1356015,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1348335,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1332975,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1325295,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1294575,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1286895,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1286895,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1279215,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1210095,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1202415,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1263855,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1256175,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1202415,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1194735,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1194735,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1187055,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1386735,&quot;xmin&quot;:559305,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:566985,&quot;width&quot;:7680}],&quot;genId&quot;:&quot;859862240&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon7b4c65cc8b47c110bd07fa20dd01c775&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anoncbfbd08b19b67d5c46001630037f640a&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
// In second element of RDD, we have details of number cols and rows of each Tile in RDD
band.map(l => l._2).take(10)
// Out:
// res17: Array[geotrellis.raster.Tile] = Array(DoubleConstantNoDataArrayTile([D@5c42a81f,256,256), DoubleConstantNoDataArrayTile([D@7068fc47,256,256), DoubleConstantNoDataArrayTile([D@4f2fb7fe,256,256), DoubleConstantNoDataArrayTile([D@72089dac,256,256), DoubleConstantNoDataArrayTile([D@3b43c1a2,256,256), DoubleConstantNoDataArrayTile([D@cfe8849,256,256), DoubleConstantNoDataArrayTile([D@3edc5e6f,256,256), DoubleConstantNoDataArrayTile([D@80f51e5,256,256), DoubleConstantNoDataArrayTile([D@2d64df97,256,256), DoubleConstantNoDataArrayTile([D@5520b6b2,256,256))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2e10516d4df0dafbb478797b3d3479db&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1001464081&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1001464081"><li>
//               <a href="#tab1001464081-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1001464081-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1001464081"><div class="tab-pane" id="tab1001464081-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon7642206bcb781c1f0642518b176887c1&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;1324744602&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["cols","rows","cellType"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon6b41aad313e7508e69098f9ed3175476&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon4bdbe8da442c3487c32d30c977962cf1&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1001464081-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anond85a7171024db73c40a9d761581328ec&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;637272024&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon46627aa2abfc7b870f323313067ed4ea&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon6b5fbb76f797208eed6cb53841fadee1&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// # We can convert ProjectedExtent to SpatialKey...
//
// In Spark - Geotrellis, instead of using ProjectedExtent, we can also use SpatialKey.
//
// A SpatialKey indicates the spatial positioning of a layer's tile. It's a grid or cube of Tiles. But in resume, we can say TileLayer is Tile simply..

// %%
// We find metadata ("or "Layer Metadata", stores information critical to Tile Layer IO.")
val (_, metadata) = band.collectMetadata[SpatialKey](FloatingLayoutScheme())

// and tiles
val tiles = band.tileToLayout[SpatialKey](metadata)
// Out:
// metadata: geotrellis.spark.TileLayerMetadata[geotrellis.spark.SpatialKey] = TileLayerMetadata(float64,GridExtent(Extent(528585.0, 1156335.0, 758985.0, 1394415.0),30.0,30.0),Extent(528585.0, 1162785.0, 755415.0, 1394415.0),EPSG:32648,KeyBounds(SpatialKey(0,0),SpatialKey(29,30)))
// tiles: org.apache.spark.rdd.RDD[(geotrellis.spark.SpatialKey, geotrellis.raster.Tile)] = ShuffledRDD[21] at reduceByKey at TileRDDMerge.scala:51

// %%
// What will we have in SpatialKey?
tiles.map(l => l._1).take(10)
// Out:
// res20: Array[geotrellis.spark.SpatialKey] = Array(SpatialKey(10,26), SpatialKey(28,27), SpatialKey(6,17), SpatialKey(0,24), SpatialKey(27,11), SpatialKey(23,1), SpatialKey(24,14), SpatialKey(14,27), SpatialKey(29,13), SpatialKey(7,3))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;an
_1&quot;:9,&quot;_2&quot;:31},{&quot;_1&quot;:10,&quot;_2&quot;:31},{&quot;_1&quot;:11,&quot;_2&quot;:31},{&quot;_1&quot;:12,&quot;_2&quot;:31},{&quot;_1&quot;:13,&quot;_2&quot;:31},{&quot;_1&quot;:14,&quot;_2&quot;:31},{&quot;_1&quot;:15,&quot;_2&quot;:31},{&quot;_1&quot;:16,&quot;_2&quot;:31},{&quot;_1&quot;:17,&quot;_2&quot;:31},{&quot;_1&quot;:18,&quot;_2&quot;:31},{&quot;_1&quot;:19,&quot;_2&quot;:31},{&quot;_1&quot;:20,&quot;_2&quot;:31},{&quot;_1&quot;:21,&quot;_2&quot;:31},{&quot;_1&quot;:22,&quot;_2&quot;:31},{&quot;_1&quot;:23,&quot;_2&quot;:31},{&quot;_1&quot;:24,&quot;_2&quot;:31},{&quot;_1&quot;:25,&quot;_2&quot;:31},{&quot;_1&quot;:26,&quot;_2&quot;:31},{&quot;_1&quot;:27,&quot;_2&quot;:31},{&quot;_1&quot;:28,&quot;_2&quot;:31},{&quot;_1&quot;:29,&quot;_2&quot;:31}],&quot;genId&quot;:&quot;1419204721&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonc982703ca00e7731031950a9ada7be54&quot;,&quot;initialValue&quot;:&quot;30&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anone45039cec7bb3c40241709dbb5ae4587&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab2036338099-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon536f9f54f3ed0483a67bd2f8c5d52b1a&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:0,&quot;_2&quot;:31},{&quot;_1&quot;:1,&quot;_2&quot;:31},{&quot;_1&quot;:2,&quot;_2&quot;:31},{&quot;_1&quot;:3,&quot;_2&quot;:31},{&quot;_1&quot;:4,&quot;_2&quot;:31},{&quot;_1&quot;:5,&quot;_2&quot;:31},{&quot;_1&quot;:6,&quot;_2&quot;:31},{&quot;_1&quot;:7,&quot;_2&quot;:31},{&quot;_1&quot;:8,&quot;_2&quot;:31},{&quot;_1&quot;:9,&quot;_2&quot;:31},{&quo

// %% [markdown]
// # From RDD[SpatialKey, Tile] to Raster

// %%
// To be able to save to HDFS, we always need to convert RDD[ProjectedExtent, Tile] to Raster[Tile]
// Here, we have many Tiles in this RDD, so we need to stitch all of them together
// In this version of Geotrellis, we always have inside RDD multiple Tile (SingleBand or MultiBand)
val raster = ContextRDD(tiles, metadata).stitch
// Out:
// raster: geotrellis.raster.Raster[geotrellis.raster.Tile] = Raster(DoubleConstantNoDataArrayTile([D@4cae1cf1,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0))

// %% [markdown]
// # From Raster to GeoTiff
//
// GeoTiff is raster data, but raster data needs to include CRS to become GeoTiff!

// %%
val geotiff = GeoTiff(raster, metadata.crs)
// Out:
// geotiff: geotrellis.raster.io.geotiff.SinglebandGeoTiff = SinglebandGeoTiff(DoubleConstantNoDataArrayTile([D@4cae1cf1,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0),EPSG:32648,Tags(Map(),List()),GeoTiffOptions(geotrellis.raster.io.geotiff.Striped@61b3336,geotrellis.raster.io.geotiff.compression.NoCompression$@1ab7c601,1,None))
