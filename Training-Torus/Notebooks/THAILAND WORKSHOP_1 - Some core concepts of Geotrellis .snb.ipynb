// %% [markdown]
// # Useful links to read :
//
// http://geotrellis.readthedocs.io/en/latest/guide/core-concepts.html
//
// Github :
// https://github.com/locationtech/geotrellis
//
// Function :
// http://geotrellis.github.io/scaladocs/latest/#geotrellis.package

// %% [markdown]
// # Import libraries

// %%
import geotrellis.proj4._

import geotrellis.spark._
import geotrellis.spark.io.hadoop._
import geotrellis.spark.io.hadoop.formats._
import geotrellis.spark.io.RasterReader
import geotrellis.spark.tiling.FloatingLayoutScheme

import geotrellis.vector._

import geotrellis.raster._
import geotrellis.raster.render._
import geotrellis.raster.io.geotiff._
import geotrellis.raster.io.geotiff.reader.GeoTiffReader
import geotrellis.raster.io.geotiff.tags.TiffTags
import geotrellis.raster.io.geotiff.GeoTiff

import org.apache.hadoop.conf.Configuration
import org.apache.hadoop.fs.Path
// Out:
// import geotrellis.proj4._
// import geotrellis.spark._
// import geotrellis.spark.io.hadoop._
// import geotrellis.spark.io.hadoop.formats._
// import geotrellis.spark.io.RasterReader
// import geotrellis.spark.tiling.FloatingLayoutScheme
// import geotrellis.vector._
// import geotrellis.raster._
// import geotrellis.raster.render._
// import geotrellis.raster.io.geotiff._
// import geotrellis.raster.io.geotiff.reader.GeoTiffReader
// import geotrellis.raster.io.geotiff.tags.TiffTags
// import geotrellis.raster.io.geotiff.GeoTiff
// import org.apache.hadoop.conf.Configuration
// import org.apache.hadoop.fs.Path

// %% [markdown]
// # Important variables (to run everytime we use Geotrellis)

// %%
// implicit variable (important variables to run the functions in the geotrellis library)
implicit val sparkContext = sc

val rr = implicitly[RasterReader[HadoopGeoTiffRDD.Options, (ProjectedExtent, Tile)]]
// Out:
// sparkContext: org.apache.spark.SparkContext = org.apache.spark.SparkContext@480af58f
// rr: geotrellis.spark.io.RasterReader[geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options,(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = geotrellis.spark.io.RasterReader$$anon$1@4b3f5a2f

// %%
// To make the notebook run more efficiently 
val options =
HadoopGeoTiffRDD.Options(
  numPartitions = Some(100)
)
// Out:
// options: geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options = Options(List(.tif, .TIF, .tiff, .TIFF),None,TIFFTAG_DATETIME,yyyy:MM:dd HH:mm:ss,Some(256),Some(100),Some(134217728),None)

// %% [markdown]
// # Parameters

// %%
val HdfsUrl = "hdfs://hupi-factory-02-01-01-01/"
val dataRepo = "user/factory02/thailand_workshop/data_usgs/"

// pour Landsat8 
val bandPath = "LC08_L1TP_125052_20171231_20180103_01_T1"
// Out:
// HdfsUrl: String = hdfs://hupi-factory-02-01-01-01/
// dataRepo: String = user/factory02/thailand_workshop/data_usgs/
// bandPath: String = LC08_L1TP_125052_20171231_20180103_01_T1

// %% [markdown]
// # Load GeoTiff from HDFS
//
// When we read GeoTiff from HDFS, we will have a RDD[ProjectedExtent, Tile]
//
// From the documents of Geotrellis, some important concepts to know beforehand :
//
// - Tile is "A grid of numeric cells that represent some data on the Earth"
// - Cell is "A single unit of data in some grid, also called a Location in GIS"
// - In ProjectedExtent, we have extent and CRS. For definition, "Extent: or "Bounding Box" represents some area on the Earth".
//
// Here we have 2 ways to read, it's just 2 different ways to do the repartition

// %%
// First option
val band = HadoopGeoTiffRDD[ProjectedExtent, Tile](
      new Path(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF"), 
      options).map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType)))
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[4] at map at <console>:109

// %%
// Second option
val band = sc.hadoopGeoTiffRDD(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF")
        .map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType))).repartition(100)
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[13] at repartition at <console>:106

// %% [markdown]
// # Inside RDD[ProjectedExtent, Tile]..

// %%
// This version of Spark divides one GeoTiff into multiples Tiles (SingleBand or MultiBand)
// So if we count the number of observations in RDD, we will have number of Tiles
println("Number of Tiles in this band is " + band.count())
// Out:
// Number of Tiles in this band is 930

// %%
// Number of Cells
println("Number of Cells in this band is " + band.map(l => l._2.toArrayDouble()).flatMap(l => l).count())
// Out:
// Number of Cells in this band is 58378481

// %%
// If we take some observations
band.take(5)
// Out:
// res9: Array[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = Array((ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@7f7de1df,256,256)), (ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@6643c8c2,256,256)), (ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@2edb1468,256,256)), (ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@2f3e6b13,256,256)), (ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@3f5d1432,256,256)))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon85f61c9e6e75cc95c3c4303aa3de7dad&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;2015834587&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul2015834587"><li>
//               <a href="#tab2015834587-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab2015834587-1"><i class="fa fa-pie-chart"/></a>
//             </li><li>
//               <a href="#tab2015834587-2"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab2015834587"><div class="tab-pane" id="tab2015834587-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anond76e21185711ec5bb48d365f64f4ac79&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7f7de1df,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@6643c8c2,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2edb1468,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2f3e6b13,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3f5d1432,256,256)&quot;}],&quot;genId&quot;:&quot;1086590540&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon76f2e1aa9b3950bcc1fd4f125e9e151d&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon19c15bbf0b354563cbdec3dc82a19004&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab2015834587-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon6b8ad1c5ad07c9b8af1681c75aca3b10&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7f7de1df,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@6643c8c2,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2edb1468,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2f3e6b13,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3f5d1432,256,256)&quot;}],&quot;genId&quot;:&quot;17177170&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pieChart'],
//       function(playground, _magicpieChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpieChart,
//     "o": {"series":"_1","p":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1892dd24247210c7bb0f97b9d072ec9e&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon01938f3c4e2cf4298aa0173886286aa4&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab2015834587-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon8e584f8ab9b6ca1cdb650636029ce125&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@7f7de1df,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@6643c8c2,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2edb1468,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2f3e6b13,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@3f5d1432,256,256)&quot;}],&quot;genId&quot;:&quot;1387952129&quot;}" type="text/x-scoped-javascript">/*<![C

// %%
// ProjectedExtent
band.map(l => l._1).take(10)
// Out:
// res11: Array[geotrellis.vector.ProjectedExtent] = Array(ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1202415.0, 712905.0, 1210095.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1256175.0, 559305.0, 1263855.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1194735.0, 636105.0, 1202415.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1187055.0, 712905.0, 1194735.0),EPSG:32648), ProjectedExtent(Extent(559305.0, 137905...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;an
&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1256175,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1202415,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1194735,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1194735,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1187055,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1386735,&quot;xmin&quot;:559305,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:566985,&quot;width&quot;:7680}],&quot;genId&quot;:&quot;1293265236&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["xmin","ymin","xmax","ymax","width","height"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon37073288d3d0bebf6fc9a41e87f36f51&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon11788e77a72842b26c50f0d858b03136&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab922385226-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone600ab99c0437a5fc550ebf3a3fdbdff&quot;,&quot;dataInit&quot;:[{&quot;ymax&quot;:1386735,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1356015,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1348335,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1332975,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1325295,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1294575,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1286895,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1286895,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1279215,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1210095,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1202415,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1263855,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1256175,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1202415,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1194735,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1194735,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1187055,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1386735,&quot;xmin&quot;:559305,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:566985,&quot;width&quot;:7680}],&quot;genId&quot;:&quot;1951128878&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon9eac07790141e4d5048b4e18a2fcb900&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon41b574ef03f0f9f8deabcf1a4096aa33&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
// In second element of RDD, we have details of number cols and rows of each Tile in RDD
band.map(l => l._2).take(10)
// Out:
// res15: Array[geotrellis.raster.Tile] = Array(DoubleConstantNoDataArrayTile([D@69cd1cc6,256,256), DoubleConstantNoDataArrayTile([D@732eb970,256,256), DoubleConstantNoDataArrayTile([D@3dd910a,256,256), DoubleConstantNoDataArrayTile([D@48106ce5,256,256), DoubleConstantNoDataArrayTile([D@493a620d,256,256), DoubleConstantNoDataArrayTile([D@4fd9b763,256,256), DoubleConstantNoDataArrayTile([D@20632a53,256,256), DoubleConstantNoDataArrayTile([D@6bdf0dfe,256,256), DoubleConstantNoDataArrayTile([D@716f2082,256,256), DoubleConstantNoDataArrayTile([D@738ff363,256,256))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon876258c6f1c7304824a7eed0067a7053&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1465463429&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1465463429"><li>
//               <a href="#tab1465463429-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1465463429-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1465463429"><div class="tab-pane" id="tab1465463429-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona3222d0c7b55bdee28a2f79dfcfc6d4a&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;1509938895&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["cols","rows","cellType"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonecc58d22a138eec3649065a1ca0a6a42&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon46ca2fe4691ea29e5438c814148c114d&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1465463429-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon332c3933b9d02b846371a146477cd092&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;2143298764&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon77c64f2bcdfd1d23c7dd0f44f92ae1b0&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon8feb7ee3af0cd1ed834a8c281b41391b&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// # We can convert ProjectedExtent to SpatialKey...
//
// In Spark - Geotrellis, instead of using ProjectedExtent, we can also use SpatialKey.
//
// A SpatialKey indicates the spatial positioning of a layer's tile. It's a grid or cube of Tiles. But in resume, we can say TileLayer is Tile simply..

// %%
// We find metadata ("or "Layer Metadata", stores information critical to Tile Layer IO.")
val (_, metadata) = band.collectMetadata[SpatialKey](FloatingLayoutScheme())

// and tiles
val tiles = band.tileToLayout[SpatialKey](metadata)
// Out:
// metadata: geotrellis.spark.TileLayerMetadata[geotrellis.spark.SpatialKey] = TileLayerMetadata(float64,GridExtent(Extent(528585.0, 1156335.0, 758985.0, 1394415.0),30.0,30.0),Extent(528585.0, 1162785.0, 755415.0, 1394415.0),EPSG:32648,KeyBounds(SpatialKey(0,0),SpatialKey(29,30)))
// tiles: org.apache.spark.rdd.RDD[(geotrellis.spark.SpatialKey, geotrellis.raster.Tile)] = ShuffledRDD[19] at reduceByKey at TileRDDMerge.scala:51

// %%
// What will we have in SpatialKey?
tiles.map(l => l._1).take(10)
// Out:
// res18: Array[geotrellis.spark.SpatialKey] = Array(SpatialKey(10,26), SpatialKey(28,27), SpatialKey(6,17), SpatialKey(0,24), SpatialKey(27,11), SpatialKey(23,1), SpatialKey(24,14), SpatialKey(14,27), SpatialKey(29,13), SpatialKey(7,3))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon6b277bfb8f8c65f1c67ed3cc7d5b5c2a&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;909925575&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul909925575"><li>
//               <a href="#tab909925575-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab909925575-1"><i class="fa fa-dot-circle-o"/></a>
//             </li><li>
//               <a href="#tab909925575-2"><i class="fa fa-line-chart"/></a>
//             </li><li>
//               <a href="#tab909925575-3"><i class="fa fa-bar-chart"/></a>
//             </li><li>
//               <a href="#tab909925575-4"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab909925575"><div class="tab-pane" id="tab909925575-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon9d2128359391e29f029d6dd252663300&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;986987755&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["col","row"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon5a3eb9404ffb3f9295080de2cc91cec5&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonee0453892a49d6a9dbc5f79430c22689&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab909925575-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonb95caaebb5533b0211aeac2b2558a695&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;701328996&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"col","y":"row","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb5546e02bbeb95f03fd9294283812636&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon6823ce15a1b3116fca103bffb1f1ac07&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab909925575-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anond54e836d185cd44de3a4852d6549e8bb&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;705719450&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/lineChart'],
//       function(playground, _magiclineChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magiclineChart,
//     "o": {"x":"col","y":"row","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonba5fda098bfd15c14c0a0011f899789a&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon19e6ee9df59ec3beb3c9d1e459fcf3a3&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// 
8,&quot;_2&quot;:31},{&quot;_1&quot;:9,&quot;_2&quot;:31},{&quot;_1&quot;:10,&quot;_2&quot;:31},{&quot;_1&quot;:11,&quot;_2&quot;:31},{&quot;_1&quot;:12,&quot;_2&quot;:31},{&quot;_1&quot;:13,&quot;_2&quot;:31},{&quot;_1&quot;:14,&quot;_2&quot;:31},{&quot;_1&quot;:15,&quot;_2&quot;:31},{&quot;_1&quot;:16,&quot;_2&quot;:31},{&quot;_1&quot;:17,&quot;_2&quot;:31},{&quot;_1&quot;:18,&quot;_2&quot;:31},{&quot;_1&quot;:19,&quot;_2&quot;:31},{&quot;_1&quot;:20,&quot;_2&quot;:31},{&quot;_1&quot;:21,&quot;_2&quot;:31},{&quot;_1&quot;:22,&quot;_2&quot;:31},{&quot;_1&quot;:23,&quot;_2&quot;:31},{&quot;_1&quot;:24,&quot;_2&quot;:31},{&quot;_1&quot;:25,&quot;_2&quot;:31},{&quot;_1&quot;:26,&quot;_2&quot;:31},{&quot;_1&quot;:27,&quot;_2&quot;:31},{&quot;_1&quot;:28,&quot;_2&quot;:31},{&quot;_1&quot;:29,&quot;_2&quot;:31}],&quot;genId&quot;:&quot;688482338&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1dced526b034bce37ad20288dd1ae516&quot;,&quot;initialValue&quot;:&quot;30&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonfdae8b2a69a7defc1200fd61c6e0763f&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab107137931-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2f83f5585b909314a97c19899ab8dfd3&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:0,&quot;_2&quot;:31},{&quot;_1&quot;:1,&quot;_2&quot;:31},{&quot;_1&quot;:2,&quot;_2&quot;:31},{&quot;_1&quot;:3,&quot;_2&quot;:31},{&quot;_1&quot;:4,&quot;_2&quot;:31},{&quot;_1&quot;:5,&quot;_2&quot;:31},{&quot;_1&quot;:6,&quot;_2&quot;:31},{&quot;_1&quot;:7,&quot;_2&quot;:31},{&quot;_1&quot;:8,&quot;_2&quot;:31},{&quot;_1&quot;:9,&quot;_2&quot;:31},{&quot;_1&quot;:1

// %% [markdown]
// # From RDD[SpatialKey, Tile] to Raster

// %%
// To be able to save to HDFS, we always need to convert RDD[ProjectedExtent, Tile] to Raster[Tile]
// Here, we have many Tiles in this RDD, so we need to stitch all of them together
// In this version of Geotrellis, we always have inside RDD multiple Tile (SingleBand or MultiBand)
val raster = ContextRDD(tiles, metadata).stitch
// Out:
// raster: geotrellis.raster.Raster[geotrellis.raster.Tile] = Raster(DoubleConstantNoDataArrayTile([D@3320c413,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0))

// %% [markdown]
// # From Raster to GeoTiff
//
// GeoTiff is raster data, but raster data needs to include CRS to become GeoTiff!

// %%
val geotiff = GeoTiff(raster, metadata.crs)
// Out:
// geotiff: geotrellis.raster.io.geotiff.SinglebandGeoTiff = SinglebandGeoTiff(DoubleConstantNoDataArrayTile([D@3320c413,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0),EPSG:32648,Tags(Map(),List()),GeoTiffOptions(geotrellis.raster.io.geotiff.Striped@2f4b5edc,geotrellis.raster.io.geotiff.compression.NoCompression$@d7febff,1,None))
