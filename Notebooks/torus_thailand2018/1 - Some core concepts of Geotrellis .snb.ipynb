// %% [markdown]
// # Useful links to read :
//
// http://geotrellis.readthedocs.io/en/latest/guide/core-concepts.html
//
// Github :
// https://github.com/locationtech/geotrellis

// %% [markdown]
// # Import libraries

// %%
import geotrellis.proj4._

import geotrellis.spark._
import geotrellis.spark.io.hadoop._
import geotrellis.spark.io.hadoop.formats._
import geotrellis.spark.io.RasterReader
import geotrellis.spark.tiling.FloatingLayoutScheme

import geotrellis.vector._

import geotrellis.raster._
import geotrellis.raster.render._
import geotrellis.raster.io.geotiff._
import geotrellis.raster.io.geotiff.reader.GeoTiffReader
import geotrellis.raster.io.geotiff.tags.TiffTags
import geotrellis.raster.io.geotiff.GeoTiff

import org.apache.hadoop.conf.Configuration
import org.apache.hadoop.fs.Path
// Out:
// import geotrellis.proj4._
// import geotrellis.spark._
// import geotrellis.spark.io.hadoop._
// import geotrellis.spark.io.hadoop.formats._
// import geotrellis.spark.io.RasterReader
// import geotrellis.spark.tiling.FloatingLayoutScheme
// import geotrellis.vector._
// import geotrellis.raster._
// import geotrellis.raster.render._
// import geotrellis.raster.io.geotiff._
// import geotrellis.raster.io.geotiff.reader.GeoTiffReader
// import geotrellis.raster.io.geotiff.tags.TiffTags
// import geotrellis.raster.io.geotiff.GeoTiff
// import org.apache.hadoop.conf.Configuration
// import org.apache.hadoop.fs.Path

// %% [markdown]
// # Important variables (to run everytime we use Geotrellis)

// %%
// implicit variable (important variables to run the functions in the geotrellis library)
implicit val sparkContext = sc

val rr = implicitly[RasterReader[HadoopGeoTiffRDD.Options, (ProjectedExtent, Tile)]]
// Out:
// sparkContext: org.apache.spark.SparkContext = org.apache.spark.SparkContext@410c68a9
// rr: geotrellis.spark.io.RasterReader[geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options,(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = geotrellis.spark.io.RasterReader$$anon$1@4829c6

// %%
// To make the notebook run more efficiently 
val options =
HadoopGeoTiffRDD.Options(
  numPartitions = Some(100)
)
// Out:
// options: geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options = Options(List(.tif, .TIF, .tiff, .TIFF),None,TIFFTAG_DATETIME,yyyy:MM:dd HH:mm:ss,Some(256),Some(100),Some(134217728),None)

// %% [markdown]
// # Parameters

// %%
val HdfsUrl = "hdfs://hupi-factory-02-01-01-01/"
val dataRepo = "user/factory02/thailand_workshop/data_usgs/"

// pour Landsat8 
val bandPath = "LC08_L1TP_125052_20171231_20180103_01_T1"
// Out:
// HdfsUrl: String = hdfs://hupi-factory-02-01-01-01/
// dataRepo: String = user/factory02/thailand_workshop/data_usgs/
// bandPath: String = LC08_L1TP_125052_20171231_20180103_01_T1

// %% [markdown]
// # Load GeoTiff from HDFS
//
// When we read GeoTiff from HDFS, we will have a RDD[ProjectedExtent, Tile]
//
// From the documents of Geotrellis, some important concepts to know beforehand :
//
// - Tile is "A grid of numeric cells that represent some data on the Earth"
// - Cell is "A single unit of data in some grid, also called a Location in GIS"
// - In ProjectedExtent, we have extent and CRS. For definition, "Extent: or "Bounding Box" represents some area on the Earth".
//
// Here we have 2 ways to read, it's just 2 different ways to do the repartition

// %%
// First option
val band = HadoopGeoTiffRDD[ProjectedExtent, Tile](
      new Path(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF"), 
      options).map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType)))
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[25] at map at <console>:142

// %%
// Second option
val band = sc.hadoopGeoTiffRDD(HdfsUrl + dataRepo + bandPath + "/" + bandPath + "_B1.TIF")
        .map(l => (l._1, l._2.convert(DoubleConstantNoDataCellType))).repartition(100)
// Out:
// band: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[34] at repartition at <console>:139

// %% [markdown]
// # Inside RDD[ProjectedExtent, Tile]..

// %%
// This version of Spark divides one GeoTiff into multiples Tiles (SingleBand or MultiBand)
// So if we count the number of observations in RDD, we will have number of Tiles
println("Number of Tiles in this band is " + band.count())
// Out:
// Number of Tiles in this band is 930

// %%
// If we take some observations
band.take(5)
// Out:
// res49: Array[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = Array((ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@49bcf5d5,256,256)), (ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@5406ae7,256,256)), (ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@b7d2ba7,256,256)), (ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@2d056ddd,256,256)), (ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648),DoubleConstantNoDataArrayTile([D@33937f5,256,256)))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2c19530b4cb8e54ed47a3caee0e32054&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;282627423&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul282627423"><li>
//               <a href="#tab282627423-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab282627423-1"><i class="fa fa-pie-chart"/></a>
//             </li><li>
//               <a href="#tab282627423-2"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab282627423"><div class="tab-pane" id="tab282627423-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon3b37e7b2158f58f49808bf6ddfefad69&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@49bcf5d5,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@5406ae7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@b7d2ba7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2d056ddd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@33937f5,256,256)&quot;}],&quot;genId&quot;:&quot;1977724640&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon324421fb6c93ee45fc015e435d9362b1&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb0a3c3b49884ad97936ad2a715e49818&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab282627423-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon1c979f505071c10a0d08fc90ac97b1f5&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@49bcf5d5,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@5406ae7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@b7d2ba7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2d056ddd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@33937f5,256,256)&quot;}],&quot;genId&quot;:&quot;1615182383&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pieChart'],
//       function(playground, _magicpieChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpieChart,
//     "o": {"series":"_1","p":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon30f19012fe61bf499d100a24763d6d0d&quot;,&quot;initialValue&quot;:&quot;5&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon31ea5b5731f561e776e7433978a288f0&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab282627423-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon78c153c999c1bac73bcc87b470262dd9&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@49bcf5d5,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@5406ae7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@b7d2ba7,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@2d056ddd,256,256)&quot;},{&quot;_1&quot;:&quot;ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648)&quot;,&quot;_2&quot;:&quot;DoubleConstantNoDataArrayTile([D@33937f5,256,256)&quot;}],&quot;genId&quot;:&quot;605358310&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../j

// %%
// ProjectedExtent
band.map(l => l._1).take(10)
// Out:
// res51: Array[geotrellis.vector.ProjectedExtent] = Array(ProjectedExtent(Extent(551625.0, 1379055.0, 559305.0, 1386735.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1348335.0, 636105.0, 1356015.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1325295.0, 712905.0, 1332975.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1286895.0, 559305.0, 1294575.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1279215.0, 636105.0, 1286895.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1202415.0, 712905.0, 1210095.0),EPSG:32648), ProjectedExtent(Extent(551625.0, 1256175.0, 559305.0, 1263855.0),EPSG:32648), ProjectedExtent(Extent(628425.0, 1194735.0, 636105.0, 1202415.0),EPSG:32648), ProjectedExtent(Extent(705225.0, 1187055.0, 712905.0, 1194735.0),EPSG:32648), ProjectedExtent(Extent(559305.0, 137905...
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anoncfb92d178c0cb313f12c0f0afba397d0&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1952561140&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1952561140"><li>
//               <a href="#tab1952561140-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1952561140-1"><i class="fa fa-pie-chart"/></a>
//             </li><li>
//               <a href="#tab1952561140-2"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1952561140"><div class="tab-pane" id="tab1952561140-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon874d13b23fed702d6356faafbe7aa8ea&quot;,&quot;dataInit&quot;:[{&quot;extent&quot;:&quot;Extent(551625.0, 1379055.0, 559305.0, 1386735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1348335.0, 636105.0, 1356015.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1325295.0, 712905.0, 1332975.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(551625.0, 1286895.0, 559305.0, 1294575.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1279215.0, 636105.0, 1286895.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1202415.0, 712905.0, 1210095.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(551625.0, 1256175.0, 559305.0, 1263855.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1194735.0, 636105.0, 1202415.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1187055.0, 712905.0, 1194735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(559305.0, 1379055.0, 566985.0, 1386735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;}],&quot;genId&quot;:&quot;1290609303&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["extent","crs"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon872d16c4a3586f3b3715e06637c0d222&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonfafbb005ba1cf859202b75040919dda8&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1952561140-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonda25aef070fee8a349ad7413a16f399c&quot;,&quot;dataInit&quot;:[{&quot;extent&quot;:&quot;Extent(551625.0, 1379055.0, 559305.0, 1386735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1348335.0, 636105.0, 1356015.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1325295.0, 712905.0, 1332975.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(551625.0, 1286895.0, 559305.0, 1294575.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1279215.0, 636105.0, 1286895.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1202415.0, 712905.0, 1210095.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(551625.0, 1256175.0, 559305.0, 1263855.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1194735.0, 636105.0, 1202415.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1187055.0, 712905.0, 1194735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(559305.0, 1379055.0, 566985.0, 1386735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;}],&quot;genId&quot;:&quot;1268734541&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pieChart'],
//       function(playground, _magicpieChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpieChart,
//     "o": {"series":"extent","p":"crs","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonbb7865a57ec08da0764aa6e79e243cd1&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon27bc3ccf6f46654d3dc932223a7b8072&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1952561140-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anoncb91c8fb25f45ffcffb859dae9bb0b99&quot;,&quot;dataInit&quot;:[{&quot;extent&quot;:&quot;Extent(551625.0, 1379055.0, 559305.0, 1386735.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(628425.0, 1348335.0, 636105.0, 1356015.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(705225.0, 1325295.0, 712905.0, 1332975.0)&quot;,&quot;crs&quot;:&quot;EPSG:32648&quot;},{&quot;extent&quot;:&quot;Extent(551625.0, 12

// %%
// In extent, we can see details 
band.map(l => l._1.extent).take(10)
// Out:
// res53: Array[geotrellis.vector.Extent] = Array(Extent(551625.0, 1379055.0, 559305.0, 1386735.0), Extent(628425.0, 1348335.0, 636105.0, 1356015.0), Extent(705225.0, 1325295.0, 712905.0, 1332975.0), Extent(551625.0, 1286895.0, 559305.0, 1294575.0), Extent(628425.0, 1279215.0, 636105.0, 1286895.0), Extent(705225.0, 1202415.0, 712905.0, 1210095.0), Extent(551625.0, 1256175.0, 559305.0, 1263855.0), Extent(628425.0, 1194735.0, 636105.0, 1202415.0), Extent(705225.0, 1187055.0, 712905.0, 1194735.0), Extent(559305.0, 1379055.0, 566985.0, 1386735.0))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2bbb5de6f2e4e0a8291aa03cdcee79f2&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;608027651&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul608027651"><li>
//               <a href="#tab608027651-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab608027651-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab608027651"><div class="tab-pane" id="tab608027651-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona2bf7b4aca2ffc82f0463ff93bc10a24&quot;,&quot;dataInit&quot;:[{&quot;ymax&quot;:1386735,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1356015,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1348335,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1332975,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1325295,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1294575,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1286895,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1286895,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1279215,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1210095,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1202415,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1263855,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1256175,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1202415,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1194735,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1194735,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1187055,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1386735,&quot;xmin&quot;:559305,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:566985,&quot;width&quot;:7680}],&quot;genId&quot;:&quot;1651254042&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["xmin","ymin","xmax","ymax","width","height"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon49c24045d1ca5abca9cb748082037b84&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb94ae4ea8863e0878e5f4c41e2f90cba&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab608027651-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonca31cd52c55e13fa94246c7382332c44&quot;,&quot;dataInit&quot;:[{&quot;ymax&quot;:1386735,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1356015,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1348335,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1332975,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1325295,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1294575,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1286895,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1286895,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1279215,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1210095,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1202415,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1263855,&quot;xmin&quot;:551625,&quot;height&quot;:7680,&quot;ymin&quot;:1256175,&quot;xmax&quot;:559305,&quot;width&quot;:7680},{&quot;ymax&quot;:1202415,&quot;xmin&quot;:628425,&quot;height&quot;:7680,&quot;ymin&quot;:1194735,&quot;xmax&quot;:636105,&quot;width&quot;:7680},{&quot;ymax&quot;:1194735,&quot;xmin&quot;:705225,&quot;height&quot;:7680,&quot;ymin&quot;:1187055,&quot;xmax&quot;:712905,&quot;width&quot;:7680},{&quot;ymax&quot;:1386735,&quot;xmin&quot;:559305,&quot;height&quot;:7680,&quot;ymin&quot;:1379055,&quot;xmax&quot;:566985,&quot;width&quot;:7680}],&quot;genId&quot;:&quot;1767810067&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2f29ec77af191700f19cddd3600a0e60&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon9a9830133696c623cbb0abc0559afb69&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
// In second element of RDD, we have details of number cols and rows of each Tile in RDD
band.map(l => l._2).take(10)
// Out:
// res55: Array[geotrellis.raster.Tile] = Array(DoubleConstantNoDataArrayTile([D@49c6ae98,256,256), DoubleConstantNoDataArrayTile([D@2e01e75b,256,256), DoubleConstantNoDataArrayTile([D@d9203cf,256,256), DoubleConstantNoDataArrayTile([D@72ece87d,256,256), DoubleConstantNoDataArrayTile([D@ea23ad6,256,256), DoubleConstantNoDataArrayTile([D@2f382f66,256,256), DoubleConstantNoDataArrayTile([D@32a9dd35,256,256), DoubleConstantNoDataArrayTile([D@2713741d,256,256), DoubleConstantNoDataArrayTile([D@38f88ea3,256,256), DoubleConstantNoDataArrayTile([D@5655c5c5,256,256))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon31064596b9c9e949c6cebdfdbc2efeee&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;809183474&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul809183474"><li>
//               <a href="#tab809183474-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab809183474-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab809183474"><div class="tab-pane" id="tab809183474-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone1c21fe124ff49d7fd2bd67930a029d7&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;57838549&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["cols","rows","cellType"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon5a23baac1d09c4c87137f8037e995b2c&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonbe9ef7b716a10fd643e7d4cd17a1a2a6&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab809183474-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon39308c5c447e411ac2ea5dda4f1492b8&quot;,&quot;dataInit&quot;:[{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;},{&quot;cols&quot;:256,&quot;rows&quot;:256,&quot;cellType&quot;:&quot;float64&quot;}],&quot;genId&quot;:&quot;382299301&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon7c408e15ede9f1b45cceb398b7c71377&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon85acbf93a8666107d2698b9ac38bd135&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// # We can convert ProjectedExtent to SpatialKey...
//
// In Spark - Geotrellis, it's recommended to use SpatialKey instead of ProjectedExtent.

// %%
// We find metadata ("or "Layer Metadata", stores information critical to Tile Layer IO.")
val (_, metadata) = band.collectMetadata[SpatialKey](FloatingLayoutScheme())

// and tiles
val tiles = band.tileToLayout[SpatialKey](metadata)
// Out:
// metadata: geotrellis.spark.TileLayerMetadata[geotrellis.spark.SpatialKey] = TileLayerMetadata(float64,GridExtent(Extent(528585.0, 1156335.0, 758985.0, 1394415.0),30.0,30.0),Extent(528585.0, 1162785.0, 755415.0, 1394415.0),EPSG:32648,KeyBounds(SpatialKey(0,0),SpatialKey(29,30)))
// tiles: org.apache.spark.rdd.RDD[(geotrellis.spark.SpatialKey, geotrellis.raster.Tile)] = ShuffledRDD[40] at reduceByKey at TileRDDMerge.scala:51

// %%
// What will we have in SpatialKey?
tiles.map(l => l._1).take(10)
// Out:
// res58: Array[geotrellis.spark.SpatialKey] = Array(SpatialKey(10,26), SpatialKey(28,27), SpatialKey(6,17), SpatialKey(0,24), SpatialKey(27,11), SpatialKey(23,1), SpatialKey(24,14), SpatialKey(14,27), SpatialKey(29,13), SpatialKey(7,3))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon9cd97474a33966f2fae64bf132626d48&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1573422821&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1573422821"><li>
//               <a href="#tab1573422821-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1573422821-1"><i class="fa fa-dot-circle-o"/></a>
//             </li><li>
//               <a href="#tab1573422821-2"><i class="fa fa-line-chart"/></a>
//             </li><li>
//               <a href="#tab1573422821-3"><i class="fa fa-bar-chart"/></a>
//             </li><li>
//               <a href="#tab1573422821-4"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1573422821"><div class="tab-pane" id="tab1573422821-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon0371e2932cb12c0f11ace278854da482&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;914341623&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["col","row"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb26a464480c740438615576ce560d7c7&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon705e33904dfb11c68b3d101f3d2c41cb&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1573422821-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon107094eb5bc76c6525a3decd52a6009f&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;322656624&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"col","y":"row","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonbc6c43e46b70a353ef948f868385090a&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonf4962797440e08e5fbce2b7a969d7427&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1573422821-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anone3c2ac8236d9bf6542c0c0250e557a50&quot;,&quot;dataInit&quot;:[{&quot;col&quot;:10,&quot;row&quot;:26},{&quot;col&quot;:28,&quot;row&quot;:27},{&quot;col&quot;:6,&quot;row&quot;:17},{&quot;col&quot;:0,&quot;row&quot;:24},{&quot;col&quot;:27,&quot;row&quot;:11},{&quot;col&quot;:23,&quot;row&quot;:1},{&quot;col&quot;:24,&quot;row&quot;:14},{&quot;col&quot;:14,&quot;row&quot;:27},{&quot;col&quot;:29,&quot;row&quot;:13},{&quot;col&quot;:7,&quot;row&quot;:3}],&quot;genId&quot;:&quot;1295350767&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/lineChart'],
//       function(playground, _magiclineChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magiclineChart,
//     "o": {"x":"col","y":"row","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon57782a71bda592dcaca8a9bda6062ad1&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2b1b4eb595a2c67d5cec3887d9672839&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA

// %% [markdown]
// # From RDD[SpatialKey, Tile] to Raster

// %%
// To be able to save to HDFS, we always need to convert RDD[ProjectedExtent, Tile] to Raster[Tile]
// Here, we have many Tiles in this RDD, so we need to stitch all of them together
// In this version of Geotrellis, we always have inside RDD multiple Tile (SingleBand or MultiBand)
val raster = ContextRDD(tiles, metadata).stitch
// Out:
// raster: geotrellis.raster.Raster[geotrellis.raster.Tile] = Raster(DoubleConstantNoDataArrayTile([D@3196b8ff,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0))

// %% [markdown]
// # From Raster to GeoTiff

// %%
val geotiff = GeoTiff(raster, metadata.crs)
// Out:
// geotiff: geotrellis.raster.io.geotiff.SinglebandGeoTiff = SinglebandGeoTiff(DoubleConstantNoDataArrayTile([D@3196b8ff,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0),EPSG:32648,Tags(Map(),List()),GeoTiffOptions(geotrellis.raster.io.geotiff.Striped@c19771e,geotrellis.raster.io.geotiff.compression.NoCompression$@12ad832,1,None))
