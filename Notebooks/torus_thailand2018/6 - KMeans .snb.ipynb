// %% [markdown]
// # Import libraries

// %%
import geotrellis.raster._
import geotrellis.raster.vectorize._
import geotrellis.raster.vectorize
import geotrellis.raster.io.geotiff._
import geotrellis.raster.render._
import geotrellis.raster.io.geotiff.GeoTiff
import geotrellis.raster.resample._

import geotrellis.spark._
import geotrellis.spark.io._
import geotrellis.spark.io.RasterReader
import geotrellis.spark.io.hadoop._
import geotrellis.spark.io.hadoop
import geotrellis.spark.tiling._
import geotrellis.spark.tiling.FloatingLayoutScheme

import geotrellis.vector._

import org.apache.spark.SparkContext
import org.apache.spark.rdd._
import org.apache.spark.rdd.RDD
import org.apache.spark.HashPartitioner
import org.apache.spark.mllib.linalg.{Vector, Vectors}
import org.apache.spark.mllib.clustering.{KMeans, KMeansModel}

import java.net.URI
import scala.math.BigDecimal.RoundingMode
import org.apache.hadoop.fs.Path
// Out:
// import geotrellis.raster._
// import geotrellis.raster.vectorize._
// import geotrellis.raster.vectorize
// import geotrellis.raster.io.geotiff._
// import geotrellis.raster.render._
// import geotrellis.raster.io.geotiff.GeoTiff
// import geotrellis.raster.resample._
// import geotrellis.spark._
// import geotrellis.spark.io._
// import geotrellis.spark.io.RasterReader
// import geotrellis.spark.io.hadoop._
// import geotrellis.spark.io.hadoop
// import geotrellis.spark.tiling._
// import geotrellis.spark.tiling.FloatingLayoutScheme
// import geotrellis.vector._
// import org.apache.spark.SparkContext
// import org.apache.spark.rdd._
// import org.apache.spark.rdd.RDD
// import org.apache.spark.HashPartitioner
// import org.apache.spark.mllib.linalg.{Vector, Vectors}
// import org.apache.spark.mllib.clustering.{KMeans, KMeansModel}
// import java....

// %% [markdown]
// # Important variables

// %%
val rr = implicitly[RasterReader[HadoopGeoTiffRDD.Options, (ProjectedExtent, Tile)]]
implicit val sparkContext = sc
// Out:
// rr: geotrellis.spark.io.RasterReader[geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options,(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = geotrellis.spark.io.RasterReader$$anon$1@1d5cfa13
// sparkContext: org.apache.spark.SparkContext = org.apache.spark.SparkContext@c9f729f

// %%
val options =
HadoopGeoTiffRDD.Options(
  numPartitions = Some(100)
)
// Out:
// options: geotrellis.spark.io.hadoop.HadoopGeoTiffRDD.Options = Options(List(.tif, .TIF, .tiff, .TIFF),None,TIFFTAG_DATETIME,yyyy:MM:dd HH:mm:ss,Some(256),Some(100),Some(134217728),None)

// %% [markdown]
// # Parameters

// %%
val HdfsUrl = "hdfs://hupi-factory-02-01-01-01/"
val dataRepo = "user/factory02/thailand_workshop/data_multiBands/"
val saveRepo = "user/factory02/thailand_workshop/kmeans/"
val landsatName = "LC08_L1TP_125052_20171231_20180103_01_T1"
val k = 20
// list of colors for PNG (17 colors for 17 models)
val allColors = "0:003366ff;1:3399ffff;2:0066ccff;3:000099ff;4:000000ff;5:006666ff;6:4dffffff;7:669999ff;8:00ccffff;9:339966ff;10:00ffccff;11:6600ffff;12:8cd98cff;13:66ffccff;14:737373ff;15:ff66ffff;16:ffff00ff;17:ff8000ff;18:cc3300ff;19:ff9f80ff"
// Out:
// HdfsUrl: String = hdfs://hupi-factory-02-01-01-01/
// dataRepo: String = user/factory02/thailand_workshop/data_multiBands/
// saveRepo: String = user/factory02/thailand_workshop/kmeans/
// landsatName: String = LC08_L1TP_125052_20171231_20180103_01_T1
// k: Int = 20
// allColors: String = 0:003366ff;1:3399ffff;2:0066ccff;3:000099ff;4:000000ff;5:006666ff;6:4dffffff;7:669999ff;8:00ccffff;9:339966ff;10:00ffccff;11:6600ffff;12:8cd98cff;13:66ffccff;14:737373ff;15:ff66ffff;16:ffff00ff;17:ff8000ff;18:cc3300ff;19:ff9f80ff

// %%
// List of k colors
val listColors = allColors.split(";").take(k).mkString(";")
// Out:
// listColors: String = 0:003366ff;1:3399ffff;2:0066ccff;3:000099ff;4:000000ff;5:006666ff;6:4dffffff;7:669999ff;8:00ccffff;9:339966ff;10:00ffccff;11:6600ffff;12:8cd98cff;13:66ffccff;14:737373ff;15:ff66ffff;16:ffff00ff;17:ff8000ff;18:cc3300ff;19:ff9f80ff

// %%
val saveAddress = HdfsUrl + saveRepo + landsatName + "/" + k
val savePath_illustration = new Path(saveAddress + ".png")
val savePath = new Path(saveAddress)
// Out:
// saveAddress: String = hdfs://hupi-factory-02-01-01-01/user/factory02/thailand_workshop/kmeans/LC08_L1TP_125052_20171231_20180103_01_T1/20
// savePath_illustration: org.apache.hadoop.fs.Path = hdfs://hupi-factory-02-01-01-01/user/factory02/thailand_workshop/kmeans/LC08_L1TP_125052_20171231_20180103_01_T1/20.png
// savePath: org.apache.hadoop.fs.Path = hdfs://hupi-factory-02-01-01-01/user/factory02/thailand_workshop/kmeans/LC08_L1TP_125052_20171231_20180103_01_T1/20

// %% [markdown]
// # To avoid duplicates in HDFS

// %%
val conf = sc.hadoopConfiguration 
val fs = org.apache.hadoop.fs.FileSystem.get(new java.net.URI(HdfsUrl), conf)
// Out:
// conf: org.apache.hadoop.conf.Configuration = Configuration: core-default.xml, core-site.xml, mapred-default.xml, mapred-site.xml, yarn-default.xml, yarn-site.xml, hdfs-default.xml, hdfs-site.xml
// fs: org.apache.hadoop.fs.FileSystem = DFS[DFSClient[clientName=DFSClient_NONMAPREDUCE_-1836628259_113, ugi=root (auth:SIMPLE)]]

// %%
// delete the model if it existed already
fs.delete(savePath,true)
// Out:
// res8: Boolean = false
// false

// %%
// delete the illustration if it existed already
fs.delete(savePath_illustration,true)
// Out:
// res10: Boolean = false
// false

// %% [markdown]
// # Load multiBandgeoTiff from HDFS

// %%
// We get multi bands from HDFS (except band 8) 
val sourceTiles = sc.hadoopMultibandGeoTiffRDD(HdfsUrl + dataRepo + landsatName + ".tif").repartition(100)
// Out:
// sourceTiles: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.MultibandTile)] = MapPartitionsRDD[7] at repartition at <console>:120

// %% [markdown]
// # Prepare input for KMeans
//
// To be able to run KMeans in Spark, we need to have RDD[Vector] as input

// %%
// We convert multi tiles into one vector of features in RDD
val rddArrayOfTiles = sourceTiles.map (l => (l._2.band(0).convert(DoubleConstantNoDataCellType).toArrayDouble(), 
                       l._2.band(1).convert(DoubleConstantNoDataCellType).toArrayDouble(), 
                       l._2.band(2).convert(DoubleConstantNoDataCellType).toArrayDouble(),
                       l._2.band(3).convert(DoubleConstantNoDataCellType).toArrayDouble(), 
                       l._2.band(4).convert(DoubleConstantNoDataCellType).toArrayDouble(),
                       l._2.band(5).convert(DoubleConstantNoDataCellType).toArrayDouble(), 
                       l._2.band(6).convert(DoubleConstantNoDataCellType).toArrayDouble(),
                       l._2.band(7).convert(DoubleConstantNoDataCellType).toArrayDouble(),
                       l._2.band(8).convert(DoubleConstantNoDataCellType).toArrayDouble(), 
                       l._2.band(9).convert(DoubleConstantNoDataCellType).toArrayDouble()))
.map(l => l._1.zip(l._2).zip(l._3).zip(l._4).zip(l._5).zip(l._6).zip(l._7).zip(l._8).zip(l._9).zip(l._10))
.map(l => l.map(k => Vectors.dense(k._1._1._1._1._1._1._1._1._1, k._1._1._1._1._1._1._1._1._2, 
                                   k._1._1._1._1._1._1._1._2, k._1._1._1._1._1._1._2,
                                  k._1._1._1._1._1._2, k._1._1._1._1._2, k._1._1._1._2,
                                   k._1._1._2, k._1._2, k._2)))
// Out:
// rddArrayOfTiles: org.apache.spark.rdd.RDD[Array[org.apache.spark.mllib.linalg.Vector]] = MapPartitionsRDD[10] at map at <console>:134

// %%
val input = rddArrayOfTiles.flatMap(l => l)
// Out:
// input: org.apache.spark.rdd.RDD[org.apache.spark.mllib.linalg.Vector] = MapPartitionsRDD[11] at flatMap at <console>:124

// %% [markdown]
// # Build a KMeans model

// %%
// We train KMeans model
val clusters = KMeans.train(input, k, 20)
// Out:
// clusters: org.apache.spark.mllib.clustering.KMeansModel = org.apache.spark.mllib.clustering.KMeansModel@172dfe7a

// %%
// Errors of the model
val WSSSE = clusters.computeCost(input)
println("Within Set Sum of Squared Errors = " + WSSSE)
// Out:
// Within Set Sum of Squared Errors = 2.775832563565558E14
// WSSSE: Double = 2.775832563565558E14

// %% [markdown]
// # Save model to HDFS

// %%
// Save model
clusters.save(sc, saveAddress)

// %%
// To load the model (for later use)
val clusters = KMeansModel.load(sc, saveAddress)
// Out:
// clusters: org.apache.spark.mllib.clustering.KMeansModel = org.apache.spark.mllib.clustering.KMeansModel@49617559

// %% [markdown]
// # To find the clusters of the input

// %%
val results = clusters.predict(input)
// Out:
// results: org.apache.spark.rdd.RDD[Int] = MapPartitionsRDD[86] at map at KMeansModel.scala:69

// %%
// number of element for each cluster
results.map(l => (l, 1)).reduceByKey(_ + _).take(10)
// Out:
// res22: Array[(Int, Int)] = Array((0,1794104), (1,19517653), (2,835845), (3,5203963), (4,3199434), (5,2355059), (6,1641372), (7,3660481), (8,392900), (9,87672))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anona3d7783d23dae793bf60615d5cc4560e&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;966744006&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul966744006"><li>
//               <a href="#tab966744006-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab966744006-1"><i class="fa fa-dot-circle-o"/></a>
//             </li><li>
//               <a href="#tab966744006-2"><i class="fa fa-line-chart"/></a>
//             </li><li>
//               <a href="#tab966744006-3"><i class="fa fa-bar-chart"/></a>
//             </li><li>
//               <a href="#tab966744006-4"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab966744006"><div class="tab-pane" id="tab966744006-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonfdb3ea03f0551ea8635fcfabc57d350d&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:0,&quot;_2&quot;:1794104},{&quot;_1&quot;:1,&quot;_2&quot;:19517653},{&quot;_1&quot;:2,&quot;_2&quot;:835845},{&quot;_1&quot;:3,&quot;_2&quot;:5203963},{&quot;_1&quot;:4,&quot;_2&quot;:3199434},{&quot;_1&quot;:5,&quot;_2&quot;:2355059},{&quot;_1&quot;:6,&quot;_2&quot;:1641372},{&quot;_1&quot;:7,&quot;_2&quot;:3660481},{&quot;_1&quot;:8,&quot;_2&quot;:392900},{&quot;_1&quot;:9,&quot;_2&quot;:87672}],&quot;genId&quot;:&quot;1846730422&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonb6f2493ebe31cd4fddd1a4ae0bab70eb&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1a77eb5a0b820621e914839424e7606a&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab966744006-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon8dbb20e4b41dc9f43977be9039682111&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:0,&quot;_2&quot;:1794104},{&quot;_1&quot;:1,&quot;_2&quot;:19517653},{&quot;_1&quot;:2,&quot;_2&quot;:835845},{&quot;_1&quot;:3,&quot;_2&quot;:5203963},{&quot;_1&quot;:4,&quot;_2&quot;:3199434},{&quot;_1&quot;:5,&quot;_2&quot;:2355059},{&quot;_1&quot;:6,&quot;_2&quot;:1641372},{&quot;_1&quot;:7,&quot;_2&quot;:3660481},{&quot;_1&quot;:8,&quot;_2&quot;:392900},{&quot;_1&quot;:9,&quot;_2&quot;:87672}],&quot;genId&quot;:&quot;151127235&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/scatterChart'],
//       function(playground, _magicscatterChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicscatterChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anone70bc54a16afe0a26b825a1a14a5b89e&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anona9b2560d9001f5d1d50dd5493546786d&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab966744006-2">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon631a1546de11e745aed8ad77971376cd&quot;,&quot;dataInit&quot;:[{&quot;_1&quot;:0,&quot;_2&quot;:1794104},{&quot;_1&quot;:1,&quot;_2&quot;:19517653},{&quot;_1&quot;:2,&quot;_2&quot;:835845},{&quot;_1&quot;:3,&quot;_2&quot;:5203963},{&quot;_1&quot;:4,&quot;_2&quot;:3199434},{&quot;_1&quot;:5,&quot;_2&quot;:2355059},{&quot;_1&quot;:6,&quot;_2&quot;:1641372},{&quot;_1&quot;:7,&quot;_2&quot;:3660481},{&quot;_1&quot;:8,&quot;_2&quot;:392900},{&quot;_1&quot;:9,&quot;_2&quot;:87672}],&quot;genId&quot;:&quot;1515717369&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/lineChart'],
//       function(playground, _magiclineChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magiclineChart,
//     "o": {"x":"_1","y":"_2","width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonde5485e8b1970a447133d6a015c448b9&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond5837c8dfbe7e75d17d186262a470e32&quot;,&quot;initialValue&quot;:&quot;&

// %%
/*
val res = input.zip(results)

// For cluster 0, we have
res.filter(l => l._2 == 0).take(100)
*/

// %% [markdown]
// # Visualization results
//
// From the multibandGeoTiff in HDFS, we will find the clusters of each pixel and create a PNG of k colors corresponding to number cluster.
//
// ### 1/ To do that, firstly, we need to find the ProjectedExtent of the results

// %%
// We zip results of clusters with index 
val resultsWithIndex = results.zipWithIndex
// Out:
// resultsWithIndex: org.apache.spark.rdd.RDD[(Int, Long)] = ZippedWithIndexRDD[89] at zipWithIndex at <console>:134

// %%
// From sourceTiles, we need to get the number of columns and rows of each tile
val nbColsAndRows = sourceTiles.map(l => (l._2.cols, l._2.rows)).zipWithIndex.map(l => (l._2, l._1))
// Out:
// nbColsAndRows: org.apache.spark.rdd.RDD[(Long, (Int, Int))] = MapPartitionsRDD[92] at map at <console>:122

// %%
// We compute lengths (number of pixels) of each tile 
val lengthTiles = nbColsAndRows.map(l => l._2._1 * l._2._2).collect()
// Out:
// lengthTiles: Array[Int] = Array(65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65536, 65...

// %%
// Then we should find the key (index of tile) for each pixel

// We compute the cumulative sum of the length of tiles
var old = 0
val cumSum = lengthTiles.map {
  case (l) => 
  {
    old = old + l
    old
  }
}

// We got the key by doing the logic below 
val resultsWithKey = resultsWithIndex.map {
  case (value, index) => 
  {
    var ind = 0
    while(index >= cumSum(ind)) {
      ind = ind + 1
    } 
    (ind, value)
  }
}
// Out:
// old: Int = 60948480
// cumSum: Array[Int] = Array(65536, 131072, 196608, 262144, 327680, 393216, 458752, 524288, 589824, 655360, 720896, 786432, 851968, 917504, 983040, 1048576, 1114112, 1179648, 1245184, 1310720, 1376256, 1441792, 1507328, 1572864, 1638400, 1703936, 1769472, 1835008, 1900544, 1966080, 2031616, 2097152, 2162688, 2228224, 2293760, 2359296, 2424832, 2490368, 2555904, 2621440, 2686976, 2752512, 2818048, 2883584, 2949120, 3014656, 3080192, 3145728, 3211264, 3276800, 3342336, 3407872, 3473408, 3538944, 3604480, 3670016, 3735552, 3801088, 3866624, 3932160, 3997696, 4063232, 4128768, 4194304, 4259840, 4325376, 4390912, 4456448, 4521984, 4587520, 4653056, 4718592, 4784128, 4849664, 4915200, 4980736, 5046272, 5111808, 5177344, 5242880, 5308416, 5373952, 5439488, 5505024, 5570560, 5...

// %%
// We group by key 
val resultsGrouped = resultsWithKey.map(l => (l._1.toLong, Array(l._2))).reduceByKey(_ ++ _)
// Out:
// resultsGrouped: org.apache.spark.rdd.RDD[(Long, Array[Int])] = ShuffledRDD[96] at reduceByKey at <console>:144

// %%
// Now we got the same count as sourceTiles.count()
// resultsGrouped.count()

// %%
// Then, we zip with index for RDD[ProjectedExtent]
val peWithIndex = sourceTiles.map(l => l._1).zipWithIndex.map(l => (l._2, l._1))
// Out:
// peWithIndex: org.apache.spark.rdd.RDD[(Long, geotrellis.vector.ProjectedExtent)] = MapPartitionsRDD[99] at map at <console>:122

// %%
// RDD of ProjectExtented with index of cluster and nb_cols and nb_rows
val peWithClusterWithColsAndRows = peWithIndex.join(resultsGrouped).join(nbColsAndRows)
// Out:
// peWithClusterWithColsAndRows: org.apache.spark.rdd.RDD[(Long, ((geotrellis.vector.ProjectedExtent, Array[Int]), (Int, Int)))] = MapPartitionsRDD[105] at join at <console>:148

// %%
// Convert to IntArrayTile
val kmeansTile = peWithClusterWithColsAndRows.map(l => (l._2._1._1, IntArrayTile(l._2._1._2, l._2._2._1, l._2._2._2).tile))
// Out:
// kmeansTile: org.apache.spark.rdd.RDD[(geotrellis.vector.ProjectedExtent, geotrellis.raster.Tile)] = MapPartitionsRDD[106] at map at <console>:150

// %% [markdown]
// ### Stiching Tiles into a single Geotiff

// %%
// Tile this RDD to a grid layout. This will transform our raster data into a
// common grid format, and merge any overlapping data.
val layoutScheme = FloatingLayoutScheme()

// We gather the metadata that we will be targeting with the tiling here.
// The return also gives us a zoom level, which we ignore.
val (_: Int, metadata: TileLayerMetadata[SpatialKey]) = kmeansTile.collectMetadata[SpatialKey](layoutScheme)
// Out:
// layoutScheme: geotrellis.spark.tiling.FloatingLayoutScheme = geotrellis.spark.tiling.FloatingLayoutScheme@46fb008f
// metadata: geotrellis.spark.TileLayerMetadata[geotrellis.spark.SpatialKey] = TileLayerMetadata(int32,GridExtent(Extent(528585.0, 1156335.0, 758985.0, 1394415.0),30.0,30.0),Extent(528585.0, 1156335.0, 758985.0, 1394415.0),EPSG:32648,KeyBounds(SpatialKey(0,0),SpatialKey(29,30)))

// %%
// Here we set some options for our tiling.
// For this example, we will set the target partitioner to one
// that has the same number of partitions as our original RDD.
val tilerOptions =
  Tiler.Options(
    resampleMethod = Bilinear,
    partitioner = new HashPartitioner(kmeansTile.partitions.length)
  )
// Out:
// tilerOptions: geotrellis.spark.tiling.Tiler.Options = Options(Bilinear,Some(org.apache.spark.HashPartitioner@64))

// %%
// Now we tile to an RDD with a SpaceTimeKey.
val tiledRdd = kmeansTile.tileToLayout[SpatialKey](metadata, tilerOptions)
// Out:
// tiledRdd: org.apache.spark.rdd.RDD[(geotrellis.spark.SpatialKey, geotrellis.raster.Tile)] = ShuffledRDD[109] at reduceByKey at TileRDDMerge.scala:48

// %%
// At this point, we want to combine our RDD and our Metadata to get a TileLayerRDD[SpatialKey]
val layerRdd: TileLayerRDD[SpatialKey] = ContextRDD(tiledRdd, metadata)
// Out:
// layerRdd: geotrellis.spark.TileLayerRDD[geotrellis.spark.SpatialKey] = ContextRDD[110] at RDD at ContextRDD.scala:35

// %%
// We stitch all tiles into one Raster
val raster_kmeans = layerRdd.stitch
// Out:
// raster_kmeans: geotrellis.raster.Raster[geotrellis.raster.Tile] = Raster(IntConstantNoDataArrayTile([I@19057a,7680,7936),Extent(528585.0, 1156335.0, 758985.0, 1394415.0))

// %% [markdown]
// ### Convert tile to png and save to HDFS

// %%
// Get color map from the application.conf settings file.
val colorMap = ColorMap.fromStringDouble(listColors).get
// Out:
// colorMap: geotrellis.raster.render.ColorMap = geotrellis.raster.render.DoubleColorMap@5da99beb

// %%
// Convert tile to png
val kmeans_png = raster_kmeans.tile.renderPng(colorMap)
// Out:
// kmeans_png: geotrellis.raster.render.Png = Png([B@6ad7fcd3)

// %%
// Save png to HDFS
kmeans_png.write(savePath_illustration)
// Out:
// No codec found for hdfs://hupi-factory-02-01-01-01/user/factory02/thailand_workshop/kmeans/LC08_L1TP_125052_20171231_20180103_01_T1/20.png, writing without compression.
