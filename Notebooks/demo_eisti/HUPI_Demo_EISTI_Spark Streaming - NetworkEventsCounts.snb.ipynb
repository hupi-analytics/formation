// %% [markdown]
// ### Spark Streaming
//
// Spark Streaming is an extension of the core Spark API that enables scalable, high-throughput,
// fault-tolerant stream processing of live data streams. Data can be ingested from many sources like
// Kafka, Flume, Kinesis, or TCP sockets, and can be processed using complex algorithms expressed
// with high-level functions like map, reduce, join and window. Finally, processed data can be
// pushed out to filesystems, databases, and live dashboards. In fact, you can apply Spark’s machine learning and graph processing algorithms on data streams.

// %% [markdown]
// First, we import the names of the Spark Streaming classes and some implicit conversions from StreamingContext into our environment in order to add useful methods to other classes we need (like DStream). StreamingContext is the main entry point for all streaming functionality. We create a local StreamingContext with two execution threads, and a batch interval of 1 second.

// %%
import org.apache.spark.streaming._
import org.apache.spark.streaming.StreamingContext._
import org.apache.spark.streaming.kafka._
import org.apache.spark.SparkConf
// Out:
// import org.apache.spark.streaming._
// import org.apache.spark.streaming.StreamingContext._
// import org.apache.spark.streaming.kafka._
// import org.apache.spark.SparkConf

// %%
//val sparkConf = new SparkConf().setAppName("DirectKafkaWordCount")
val sparkConf = new SparkConf().setAppName("Test Kafka2") //sparkContext.getConf
val ssc =  new StreamingContext(sparkContext, Seconds(10))
ssc.checkpoint("checkpoint")
//val Array(zkQuorum, group, topics, numThreads) = args*/
val zkQuorum = "ecoles.node1.pro.hupi.loc"
val group = "DEMO_HUPI_VINCENT"
val topics = "ecoles_hupilytics_scandivie"
val numThreads = "1"
// Out:
// sparkConf: org.apache.spark.SparkConf = org.apache.spark.SparkConf@14232954
// ssc: org.apache.spark.streaming.StreamingContext = org.apache.spark.streaming.StreamingContext@691a570d
// zkQuorum: String = ecoles.node1.pro.hupi.loc
// group: String = DEMO_HUPI_VINCENT
// topics: String = ecoles_hupilytics_scandivie
// numThreads: String = 1

// %% [markdown]
// # On imprime les événements et on compte les network_events

// %%
val topicMap = topics.split(",").map((_, numThreads.toInt)).toMap
// Out:
// topicMap: scala.collection.immutable.Map[String,Int] = Map(ecoles_hupilytics_scandivie -> 1)

// %%
val lines = KafkaUtils.createStream(ssc, zkQuorum, group, topicMap).map(_._2)
// Out:
// lines: org.apache.spark.streaming.dstream.DStream[String] = org.apache.spark.streaming.dstream.MappedDStream@158717b4

// %%
val words = lines.flatMap(_.split(" "))
// Out:
// words: org.apache.spark.streaming.dstream.DStream[String] = org.apache.spark.streaming.dstream.FlatMappedDStream@74b649df

// %%
val wordCounts = words.map(x => (x, 1L)).reduceByKeyAndWindow(_ + _, _ - _, Seconds(10), Seconds(10), 1)
// Out:
// wordCounts: org.apache.spark.streaming.dstream.DStream[(String, Long)] = org.apache.spark.streaming.dstream.ReducedWindowedDStream@4d8347bf

// %%
// Il faut déterminer Output avant de démarrer le Spark Streaming
wordCounts.print()

// %%
ssc.start()
ssc.awaitTermination()
// Out:
// -------------------------------------------
// Time: 1517239960000 ms
// -------------------------------------------
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","action_name":"Cocotte,1)
// (fonte"],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:51:57.000Z","urlref_domain":"search.lilo.org","@version":"1","gt_ms":947,"client":"scandivie","fla":false,"lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"86.200.132.173","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"urlref":"https://search.lilo.org/searchweb.php?q=fer+a+gaufre+en+fonte","os":"Mac,2)
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","e_n":"6","event_date":"2018-01-29","action":"add","catchbox_ts":1517239630,"gears":false,"send_image":"0","res":"2560x1600","qt":false,"cookie":"1","_pkc":"[3,21,271]","ag":false,"ip":"88.171.175.198","refts":1517239629,"idn":0,"_pks":"6","viewts":1517239629,"_pkn":",1)
// (blanc,1)
// ("],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:49:43.000Z","@version":"1","gt_ms":773,"client":"scandivie","lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"77.136.83.175","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"os":"Android","h":15,"idts":1517237381,"m":49,"url":"https://www.skeppshult-boutique.fr/gaufrier-gaufre-gateau-fonte.html?gclid=CjwKCAiAqbvTBRAPEiwANEkyCB_wOXtjHHf3HcLVRGkmGWO672tsptAkX92VpnXkKkksF1BAugbEahoCaj4QAvD_BwE","r":"276576","@timestamp":"2018-01-29T14:49:43.000Z","s":41,"idts_date":"2018-01-29T14:49:41.000Z","url_domain":"www.skeppshult","os_name":"Android"},1)
// (sp?ciale,1)
// (Safari/604.1","event_timestamp":"2018-01-29T14:55:47.000Z","rec":"1","current_ts":1517237747,"ref":"https://www.google.fr/","major":"11","action_name":"Ustensiles,1)
// ({"idsite":"1","minor":"0","viewts_date":"2018-01-29T14:55:08.000Z","os_minor":"2","os_major":"11","visitor_id":"a09be582a3b4ac7d","cvar":{"1":["current_ts","1517237707"],"42":["lang","FR"]},"ua":"Mozilla/5.0,1)
// (scandinaves","event_date":"2018-01-29","@version":"1","gt_ms":773,"client":"scandivie","action":"add","lang":"FR","catchbox_ts":1517238215,"send_image":"0","res":"1080x1920","geoip":{"timezone":"Europe/Paris","ip":"77.154.202.81","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"cookie":"1","os":"Android","ip":"77.154.202.81","refts":0,"h":16,"idts":1517230123,"m":3,"url":"https://www.skeppshult-boutique.fr/?gclid=EAIaIQobChMIro3-2Lj92AIVybfACh2OugowEAAYASAAEgIauvD_BwE","products_impression":"6,63,25,61","tags":["_grokparsefailure"],"r":"677478","idn":0,"@timestamp":"2018-01-29T15:03:35.000Z","s":36,"idts_date":"2018-01-29T12:48:43.000Z","viewts":1517238217,"name":"Samsung,1)
// ((X11;,4)
// ...
//
// -------------------------------------------
// Time: 1517239970000 ms
// -------------------------------------------
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","action_name":"Cocotte,0)
// (fonte"],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:51:57.000Z","urlref_domain":"search.lilo.org","@version":"1","gt_ms":947,"client":"scandivie","fla":false,"lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"86.200.132.173","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"urlref":"https://search.lilo.org/searchweb.php?q=fer+a+gaufre+en+fonte","os":"Mac,0)
// (naturelle,,0)
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","e_n":"6","event_date":"2018-01-29","action":"add","catchbox_ts":1517239630,"gears":false,"send_image":"0","res":"2560x1600","qt":false,"cookie":"1","_pkc":"[3,21,271]","ag":false,"ip":"88.171.175.198","refts":1517239629,"idn":0,"_pks":"6","viewts":1517239629,"_pkn":",0)
// (blanc,0)
// ("],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:49:43.000Z","@version":"1","gt_ms":773,"client":"scandivie","lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"77.136.83.175","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"os":"Android","h":15,"idts":1517237381,"m":49,"url":"https://www.skeppshult-boutique.fr/gaufrier-gaufre-gateau-fonte.html?gclid=CjwKCAiAqbvTBRAPEiwANEkyCB_wOXtjHHf3HcLVRGkmGWO672tsptAkX92VpnXkKkksF1BAugbEahoCaj4QAvD_BwE","r":"276576","@timestamp":"2018-01-29T14:49:43.000Z","s":41,"idts_date":"2018-01-29T14:49:41.000Z","url_domain":"www.skeppshult","os_name":"Android"},0)
// (Safari/604.1","event_timestamp":"2018-01-29T14:55:47.000Z","rec":"1","current_ts":1517237747,"ref":"https://www.google.fr/","major":"11","action_name":"Ustensiles,0)
// ({"idsite":"1","minor":"0","viewts_date":"2018-01-29T14:55:08.000Z","os_minor":"2","os_major":"11","visitor_id":"a09be582a3b4ac7d","cvar":{"1":["current_ts","1517237707"],"42":["lang","FR"]},"ua":"Mozilla/5.0,0)
// (scandinaves","event_date":"2018-01-29","@version":"1","gt_ms":773,"client":"scandivie","action":"add","lang":"FR","catchbox_ts":1517238215,"send_image":"0","res":"1080x1920","geoip":{"timezone":"Europe/Paris","ip":"77.154.202.81","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"cookie":"1","os":"Android","ip":"77.154.202.81","refts":0,"h":16,"idts":1517230123,"m":3,"url":"https://www.skeppshult-boutique.fr/?gclid=EAIaIQobChMIro3-2Lj92AIVybfACh2OugowEAAYASAAEgIauvD_BwE","products_impression":"6,63,25,61","tags":["_grokparsefailure"],"r":"677478","idn":0,"@timestamp":"2018-01-29T15:03:35.000Z","s":36,"idts_date":"2018-01-29T12:48:43.000Z","viewts":1517238217,"name":"Samsung,0)
// ((X11;,0)
// ...
//
// -------------------------------------------
// Time: 1517239980000 ms
// -------------------------------------------
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","action_name":"Cocotte,0)
// (fonte"],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:51:57.000Z","urlref_domain":"search.lilo.org","@version":"1","gt_ms":947,"client":"scandivie","fla":false,"lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"86.200.132.173","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"urlref":"https://search.lilo.org/searchweb.php?q=fer+a+gaufre+en+fonte","os":"Mac,0)
// (Safari/603.1.30","rec":"1","current_ts":1517239630,"ref":"https://www.google.fr/","java":true,"major":"10","e_n":"6","event_date":"2018-01-29","action":"add","catchbox_ts":1517239630,"gears":false,"send_image":"0","res":"2560x1600","qt":false,"cookie":"1","_pkc":"[3,21,271]","ag":false,"ip":"88.171.175.198","refts":1517239629,"idn":0,"_pks":"6","viewts":1517239629,"_pkn":",0)
// (Safari/604.1","event_timestamp":"2018-01-29T15:23:12.000Z","rec":"1","current_ts":1517239392,"ref":"http://www.skeppshult.fr/","major":"11","action_name":"Skeppshult,0)
// (blanc,0)
// ("],"5":["_pkc","[3,63,276]"],"42":["lang","FR"]},"event_timestamp":"2018-01-29T14:49:43.000Z","@version":"1","gt_ms":773,"client":"scandivie","lang":"FR","geoip":{"timezone":"Europe/Paris","ip":"77.136.83.175","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"os":"Android","h":15,"idts":1517237381,"m":49,"url":"https://www.skeppshult-boutique.fr/gaufrier-gaufre-gateau-fonte.html?gclid=CjwKCAiAqbvTBRAPEiwANEkyCB_wOXtjHHf3HcLVRGkmGWO672tsptAkX92VpnXkKkksF1BAugbEahoCaj4QAvD_BwE","r":"276576","@timestamp":"2018-01-29T14:49:43.000Z","s":41,"idts_date":"2018-01-29T14:49:41.000Z","url_domain":"www.skeppshult","os_name":"Android"},0)
// (Safari/604.1","event_timestamp":"2018-01-29T14:55:47.000Z","rec":"1","current_ts":1517237747,"ref":"https://www.google.fr/","major":"11","action_name":"Ustensiles,0)
// ({"idsite":"1","minor":"0","viewts_date":"2018-01-29T14:55:08.000Z","os_minor":"2","os_major":"11","visitor_id":"a09be582a3b4ac7d","cvar":{"1":["current_ts","1517237707"],"42":["lang","FR"]},"ua":"Mozilla/5.0,0)
// (scandinaves","event_date":"2018-01-29","@version":"1","gt_ms":773,"client":"scandivie","action":"add","lang":"FR","catchbox_ts":1517238215,"send_image":"0","res":"1080x1920","geoip":{"timezone":"Europe/Paris","ip":"77.154.202.81","latitude":48.8582,"country_name":"France","country_code2":"FR","continent_code":"EU","country_code3":"FR","location":[48.8582,2.3387000000000002],"real_region_name":null,"longitude":2.3387000000000002},"cookie":"1","os":"Android","ip":"77.154.202.81","refts":0,"h":16,"idts":1517230123,"m":3,"url":"https://www.skeppshult-boutique.fr/?gclid=EAIaIQobChMIro3-2Lj92AIVybfACh2OugowEAAYASAAEgIauvD_BwE","products_impression":"6,63,25,61","tags":["_grokparsefailure"],"r":"677478","idn":0,"@timestamp":"2018-01-29T15:03:35.000Z","s":36,"idts_date":"2018-01-29T12:48:43.000Z","viewts":1517238217,"name":"Samsung,0)
// (X","realp":false,"h":16,"idts":1517239974,"m":32,"url":"https://www.scandi-vie.com/cuisine-crepiere-chandeleur-fonte.html","r":"019797","@timestamp":"2018-01-29T15:32:56.000Z","s":53,"pdf":true,"idts_date":"2018-01-29T15:32:54.000Z","url_domain":"www.scandi","os_name":"Mac,1)
// The cell was cancelled.

// %%
ssc.stop()
