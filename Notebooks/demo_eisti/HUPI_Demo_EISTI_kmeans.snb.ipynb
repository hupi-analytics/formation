// %% [markdown]
// # Importer les librairies

// %%
import org.apache.spark.mllib.clustering.{KMeans, KMeansModel}
import org.apache.spark.mllib.linalg.Vectors
// Out:
// import org.apache.spark.mllib.clustering.{KMeans, KMeansModel}
// import org.apache.spark.mllib.linalg.Vectors

// %% [markdown]
// # Lire les données dans HDFS

// %%
// On lit le fichier products.csv dans HDFS
val data = sparkSession.read.format("csv")
.option("header", "true")
.option("inferSchema", "true")
.option("delimiter", ",")
.csv("hdfs://ecoles.node1.pro.hupi.loc:8020/user/ecoles/kmeans/iris.csv")
// Out:
// data: org.apache.spark.sql.DataFrame = [sepal_length: double, sepal_width: double ... 3 more fields]

// %%
data.printSchema()
// Out:
// root
//  |-- sepal_length: double (nullable = true)
//  |-- sepal_width: double (nullable = true)
//  |-- petal_length: double (nullable = true)
//  |-- petal_width: double (nullable = true)
//  |-- species: string (nullable = true)

// %% [markdown]
// # Préparer input pour créer le modèle

// %%
// Convertir en rdd (car il faut un RDD comme input quand on crée un KMeans model dans MLLib)
val rdd_data = data.map {
  case org.apache.spark.sql.Row (sepalLenght, sepalWidth, petalLength, petalWidth, species) => {
    (sepalLenght.asInstanceOf[Double], sepalWidth.asInstanceOf[Double],
     petalLength.asInstanceOf[Double], petalWidth.asInstanceOf[Double],
     species.asInstanceOf[String])
  }
}.rdd
// Out:
// rdd_data: org.apache.spark.rdd.RDD[(Double, Double, Double, Double, String)] = MapPartitionsRDD[18] at rdd at <console>:77

// %%
rdd_data.take(10)
// Out:
// res11: Array[(Double, Double, Double, Double, String)] = Array((5.1,3.5,1.4,0.2,setosa), (4.9,3.0,1.4,0.2,setosa), (4.7,3.2,1.3,0.2,setosa), (4.6,3.1,1.5,0.2,setosa), (5.0,3.6,1.4,0.2,setosa), (5.4,3.9,1.7,0.4,setosa), (4.6,3.4,1.4,0.3,setosa), (5.0,3.4,1.5,0.2,setosa), (4.4,2.9,1.4,0.2,setosa), (4.9,3.1,1.5,0.1,setosa))
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon465f5d126fe6277b0f34acc90a649c37&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1201577396&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1201577396"><li>
//               <a href="#tab1201577396-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1201577396-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1201577396"><div class="tab-pane" id="tab1201577396-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon98892186307777e099a5be2a1b1e4279&quot;,&quot;dataInit&quot;:[{&quot;_3&quot;:1.4,&quot;_2&quot;:3.5,&quot;_1&quot;:5.1,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3,&quot;_1&quot;:4.9,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.3,&quot;_2&quot;:3.2,&quot;_1&quot;:4.7,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.1,&quot;_1&quot;:4.6,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3.6,&quot;_1&quot;:5,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.7,&quot;_2&quot;:3.9,&quot;_1&quot;:5.4,&quot;_4&quot;:0.4,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3.4,&quot;_1&quot;:4.6,&quot;_4&quot;:0.3,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.4,&quot;_1&quot;:5,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:2.9,&quot;_1&quot;:4.4,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.1,&quot;_1&quot;:4.9,&quot;_4&quot;:0.1,&quot;_5&quot;:&quot;setosa&quot;}],&quot;genId&quot;:&quot;1239216990&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["_1","_2","_3","_4","_5"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2aeb8990b02db0d3838d1129e2e88c28&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonf61c3019fa140b3e5db26a26ef193f6d&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1201577396-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonb634abeea35ceff493f110775e7895a7&quot;,&quot;dataInit&quot;:[{&quot;_3&quot;:1.4,&quot;_2&quot;:3.5,&quot;_1&quot;:5.1,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3,&quot;_1&quot;:4.9,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.3,&quot;_2&quot;:3.2,&quot;_1&quot;:4.7,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.1,&quot;_1&quot;:4.6,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3.6,&quot;_1&quot;:5,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.7,&quot;_2&quot;:3.9,&quot;_1&quot;:5.4,&quot;_4&quot;:0.4,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:3.4,&quot;_1&quot;:4.6,&quot;_4&quot;:0.3,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.4,&quot;_1&quot;:5,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.4,&quot;_2&quot;:2.9,&quot;_1&quot;:4.4,&quot;_4&quot;:0.2,&quot;_5&quot;:&quot;setosa&quot;},{&quot;_3&quot;:1.5,&quot;_2&quot;:3.1,&quot;_1&quot;:4.9,&quot;_4&quot;:0.1,&quot;_5&quot;:&quot;setosa&quot;}],&quot;genId&quot;:&quot;2010736747&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2abcfa075bc379b4e6cac563929a4f7c&quot;,&quot;initialValue&quot;:&quot;10&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon10ab1b9f162ce8e81bafb69b7b33a666&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
// On ne sélectionne que les features
val input = rdd_data.map(s => Vectors.dense(s._1, s._2, s._3, s._4)).cache()
// Out:
// input: org.apache.spark.rdd.RDD[org.apache.spark.mllib.linalg.Vector] = MapPartitionsRDD[19] at map at <console>:74

// %% [markdown]
// # Créer un modèle KMeans

// %%
// Cluster the data into two classes using KMeans
val numClusters = 3 
val numIterations = 20
val clusters = KMeans.train(input, numClusters, numIterations)
// Out:
// numClusters: Int = 3
// numIterations: Int = 20
// clusters: org.apache.spark.mllib.clustering.KMeansModel = org.apache.spark.mllib.clustering.KMeansModel@270cc3da

// %%
// Evaluate clustering by computing Within Set Sum of Squared Errors
val WSSSE = clusters.computeCost(input)
println("Within Set Sum of Squared Errors = " + WSSSE)

/*
// Pour enregistrer en HDFS et recharge le modèle
clusters.save(sc, "target/org/apache/spark/KMeansExample/KMeansModel")
val sameModel = KMeansModel.load(sc, "target/org/apache/spark/KMeansExample/KMeansModel")
*/
// Out:
// Within Set Sum of Squared Errors = 78.94506582597637
// WSSSE: Double = 78.94506582597637

// %% [markdown]
// # Convertir en PMML

// %%
// Pour imprimer le modèle en PMML (ce qu'il faut copier-coller pour créer endpoint predict)
println("PMML Model:\n" + clusters.toPMML)
// Out:
// PMML Model:
// <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
// <PMML version="4.2" xmlns="http://www.dmg.org/PMML-4_2">
//     <Header description="k-means clustering">
//         <Application name="Apache Spark MLlib" version="2.1.1"/>
//         <Timestamp>2018-01-29T16:36:16</Timestamp>
//     </Header>
//     <DataDictionary numberOfFields="4">
//         <DataField name="field_0" optype="continuous" dataType="double"/>
//         <DataField name="field_1" optype="continuous" dataType="double"/>
//         <DataField name="field_2" optype="continuous" dataType="double"/>
//         <DataField name="field_3" optype="continuous" dataType="double"/>
//     </DataDictionary>
//     <ClusteringModel modelName="k-means" functionName="clustering" modelClass="centerBased" numberOfClusters="3">
//         <MiningSchema>
//             <MiningField name="field_0" usageType="active"/>
//             <MiningField name="field_1" usageType="active"/>
//             <MiningField name="field_2" usageType="active"/>
//             <MiningField name="field_3" usageType="active"/>
//         </MiningSchema>
//         <ComparisonMeasure kind="distance">
//             <squaredEuclidean/>
//         </ComparisonMeasure>
//         <ClusteringField field="field_0" compareFunction="absDiff"/>
//         <ClusteringField field="field_1" compareFunction="absDiff"/>
//         <ClusteringField field="field_2" compareFunction="absDiff"/>
//         <ClusteringField field="field_3" compareFunction="absDiff"/>
//         <Cluster name="cluster_0">
//             <Array n="4" type="real">6.853846153846153 3.0769230769230766 5.715384615384615 2.053846153846153</Array>
//         </Cluster>
//         <Cluster name="cluster_1">
//             <Array n="4" type="real">5.005999999999999 3.4180000000000006 1.4640000000000002 0.2439999999999999</Array>
//         </Cluster>
//         <Cluster name="cluster_2">
//             <Array n="4" type="real">5.88360655737705 2.7409836065573776 4.388524590163936 1.4344262295081969</Array>
//         </Cluster>
//     </ClusteringModel>
// </PMML>

// %%
/*
// Export the model to a local file in PMML format
clusters.toPMML("/tmp/kmeans.xml")

// Export the model to a directory on a distributed file system in PMML format
clusters.toPMML(sc, "/tmp/kmeans")
*/
