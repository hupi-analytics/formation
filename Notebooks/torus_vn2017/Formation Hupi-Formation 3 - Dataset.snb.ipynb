// %% [markdown]
// In this section, we will borrow the same example like Formation 1 : Word Count example but instead of working with RDD, we'll work with Dataset.
//
// The definition of Dataset is "a strongly typed collection of domain-specific objects that can be transformed in parallel using functional or relational operations. Each dataset also has an untyped view called a DataFrame, which is a Dataset of Row." (source : https://spark.apache.org/docs/2.1.0/api/java/org/apache/spark/sql/Dataset.html)
//
// In short, we can say that Dataset combines RDD and Dataframe with higher performance. In short, we can operate transformations of RDD inside a Dataset that has a structured schema like Dataframe.
//
// Let's try to do the word count with Dataset!
//
// For more explanation : http://blog.madhukaraphatak.com/introduction-to-spark-two-part-2/

// %% [markdown]
// ### Firstly, to work with Dataset, we always need to import the library of SparkSession (entry point for Dataset API like sc, entry point for RDD)

// %%
import org.apache.spark.sql.SparkSession
// Out:
// import org.apache.spark.sql.SparkSession

// %% [markdown]
// ### And define its parameters and change the configurations (if necessary)..

// %%
val sparkSession = SparkSession.builder
      .master("local")
      .appName("WordCountExample")
      .getOrCreate()
// Out:
// sparkSession: org.apache.spark.sql.SparkSession = org.apache.spark.sql.SparkSession@620f8a03

// %% [markdown]
// ### Read data from HDFS

// %%
import sparkSession.implicits._
val data = sparkSession.read.text("hdfs://hupi-factory-02-01-01-01/user/hupi/dataset_torusVN/WordCountDataset.txt").as[String]
// Out:
// import sparkSession.implicits._
// data: org.apache.spark.sql.Dataset[String] = [value: string]

// %% [markdown]
// ### In a Dataset, we can do some transformations like for RDD

// %%
data.filter(l => l.contains("the")).take(1)
// Out:
// res10: Array[String] = Array(A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.)
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon2ac94e7708385bdd28e08b904fc04a59&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;720664283&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul720664283"><li>
//               <a href="#tab720664283-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab720664283-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab720664283"><div class="tab-pane" id="tab720664283-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonfefe6a131ea4a3b4e11e8a673fdb24f5&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;}],&quot;genId&quot;:&quot;2030603559&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["string value"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond29b4348a7a029965924621acd09ca5f&quot;,&quot;initialValue&quot;:&quot;1&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anonc8476d7c456f7263c404a11f7f6da333&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab720664283-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon51069f052e46d43d423f6eab9f0062f2&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;}],&quot;genId&quot;:&quot;1489447930&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon0cfe78d1c45383feb0f14598ea123379&quot;,&quot;initialValue&quot;:&quot;1&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon1b8620dd1d4ad1d71981f284b12c95b1&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %%
data.count()
// Out:
// res12: Long = 4
// 4

// %%
data.take(2)
// Out:
// res14: Array[String] = Array(A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles., Internally, each RDD is characterized by five main properties:)
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon5b39c055c76fe8e64293ef18b7d815ce&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;1635664561&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul1635664561"><li>
//               <a href="#tab1635664561-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab1635664561-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab1635664561"><div class="tab-pane" id="tab1635664561-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonfa4718bfb35666b47cb71d7ecb7cf56e&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;},{&quot;string value&quot;:&quot;Internally, each RDD is characterized by five main properties:&quot;}],&quot;genId&quot;:&quot;2086148118&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["string value"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon2b54ac7c3c1b9ae06ad66fb2c07c2f2a&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon37e997887d5b186ccb8af0de52db43e6&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab1635664561-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon800af5937ba19a8fcb1e64ee48bf83a8&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;},{&quot;string value&quot;:&quot;Internally, each RDD is characterized by five main properties:&quot;}],&quot;genId&quot;:&quot;617150971&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anond16cc7059a2fcca38709260bae000294&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon25eb231e70616dd9a0e0b6c7143dfea0&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// ### We can also apply function that we use for Dataframe

// %%
data.printSchema()
// Out:
// root
//  |-- value: string (nullable = true)

// %%
data.show()
// Out:
// +--------------------+
// |               value|
// +--------------------+
// |A Resilient Distr...|
// |Internally, each ...|
// |- A list of parti...|
// |All of the schedu...|
// +--------------------+

// %%
data.select("value").take(2)
// Out:
// res20: Array[org.apache.spark.sql.Row] = Array([A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.], [Internally, each RDD is characterized by five main properties:])
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonef23f930f4ba74cbf7ee132495fe19a1&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;74890335&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul74890335"><li>
//               <a href="#tab74890335-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab74890335-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab74890335"><div class="tab-pane" id="tab74890335-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonce056abd9fd08c1934fe768843d6d482&quot;,&quot;dataInit&quot;:[{&quot;value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;},{&quot;value&quot;:&quot;Internally, each RDD is characterized by five main properties:&quot;}],&quot;genId&quot;:&quot;1577687722&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["value"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon09837f197f6fbe15220b0c03dbe7294c&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon9b38e7662916e4047b5aeb37247e11ad&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab74890335-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anonafdb87cc843c81f08597d74e7bfa5dd0&quot;,&quot;dataInit&quot;:[{&quot;value&quot;:&quot;A Resilient Distributed Dataset (RDD), the basic abstraction in Spark. Represents an immutable, partitioned collection of elements that can be operated on in parallel. This class contains the basic operations available on all RDDs, such as map, filter, and persist. In addition, PairRDDFunctions contains operations available only on RDDs of key-value pairs, such as groupByKey and join; DoubleRDDFunctions contains operations available only on RDDs of Doubles; and SequenceFileRDDFunctions contains operations available on RDDs that can be saved as SequenceFiles.&quot;},{&quot;value&quot;:&quot;Internally, each RDD is characterized by five main properties:&quot;}],&quot;genId&quot;:&quot;761694217&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon16e7bc0250bad2da67773087b67f66ab&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anoneb3273e587d2ca5b21be28fb7698a40c&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// ### Back to the Word Count Example, after having the Dataset data, we need to do flatMap inside Dataset and convert to Dataset of words

// %%
val words = data.flatMap(value => value.split("\\s+")) // or split(" ")
// Out:
// words: org.apache.spark.sql.Dataset[String] = [value: string]

// %%
words.take(2)
// Out:
// res23: Array[String] = Array(A, Resilient)
// <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon06ecec6694ecdc6b011689b9c6aca9aa&quot;,&quot;dataInit&quot;:[],&quot;genId&quot;:&quot;739344309&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tabs'],
//       function(playground, _magictabs) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictabs,
//     "o": {}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <div>
//         <ul class="nav nav-tabs" id="ul739344309"><li>
//               <a href="#tab739344309-0"><i class="fa fa-table"/></a>
//             </li><li>
//               <a href="#tab739344309-1"><i class="fa fa-cubes"/></a>
//             </li></ul>
//
//         <div class="tab-content" id="tab739344309"><div class="tab-pane" id="tab739344309-0">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon0e57105ec9606adf16341b893f317a50&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A&quot;},{&quot;string value&quot;:&quot;Resilient&quot;}],&quot;genId&quot;:&quot;536417016&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/tableChart'],
//       function(playground, _magictableChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magictableChart,
//     "o": {"headers":["string value"],"width":600,"height":400}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anona64df63a132804d6317267923a2175b2&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon7ae6632438604c562dfd725a0dcaa230&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div><div class="tab-pane" id="tab739344309-1">
//             <div>
//       <script data-this="{&quot;dataId&quot;:&quot;anon5d06e0f3becbbad50f3f4425f03378b3&quot;,&quot;dataInit&quot;:[{&quot;string value&quot;:&quot;A&quot;},{&quot;string value&quot;:&quot;Resilient&quot;}],&quot;genId&quot;:&quot;633878878&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/req(['../javascripts/notebook/playground','../javascripts/notebook/magic/pivotChart'],
//       function(playground, _magicpivotChart) {
//         // data ==> data-this (in observable.js's scopedEval) ==> this in JS => { dataId, dataInit, ... }
//         // this ==> scope (in observable.js's scopedEval) ==> this.parentElement ==> div.container below (toHtml)
//
//         playground.call(data,
//                         this
//                         ,
//                         {
//     "f": _magicpivotChart,
//     "o": {"width":600,"height":400,"derivedAttributes":{},"extraOptions":{}}
//   }
//
//
//
//                       );
//       }
//     );/*]]>*/</script>
//     <div>
//       <span class="chart-total-item-count"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon06ac118144362b63f0aa30cd9be4e12b&quot;,&quot;initialValue&quot;:&quot;2&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p> entries total</span>
//       <span class="chart-sampling-warning"><p data-bind="text: value"><script data-this="{&quot;valueId&quot;:&quot;anon403191a6d82aa6c63b9db230ff872a88&quot;,&quot;initialValue&quot;:&quot;&quot;}" type="text/x-scoped-javascript">/*<![CDATA[*/
// req(
// ['observable', 'knockout'],
// function (O, ko) {
//   ko.applyBindings({
//       value: O.makeObservable(valueId, initialValue)
//     },
//     this
//   );
// });
//         /*]]>*/</script></p></span>
//       <div>
//       </div>
//     </div></div>
//             </div></div>
//       </div>
//     </div></div>

// %% [markdown]
// ### Next, we convert all into lower case and then do groupByKey

// %%
val groupedWords = words.groupByKey(_.toLowerCase)
// Out:
// groupedWords: org.apache.spark.sql.KeyValueGroupedDataset[String,String] = org.apache.spark.sql.KeyValueGroupedDataset@5d8d2924

// %% [markdown]
// ### And finally, we do count() to have list of count of each words

// %%
val counts = groupedWords.count()
// Out:
// counts: org.apache.spark.sql.Dataset[(String, Long)] = [value: string, count(1): bigint]

// %%
counts.show()
// Out:
// +-----------------+--------+
// |            value|count(1)|
// +-----------------+--------+
// |          indeed,|       1|
// |            (e.g.|       3|
// |          reading|       1|
// |hash-partitioned)|       1|
// |         methods,|       1|
// |               by|       2|
// |            based|       1|
// |              new|       1|
// |              own|       1|
// |             more|       1|
// |       collection|       1|
// |            saved|       1|
// |          itself.|       1|
// |              can|       3|
// |         allowing|       1|
// |              for|       5|
// |             main|       1|
// |           please|       1|
// |         operated|       1|
// |               in|       4|
// +-----------------+--------+
// only showing top 20 rows
